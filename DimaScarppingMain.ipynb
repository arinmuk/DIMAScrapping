# %%
# Dependencies
import requests
import json
import html
#from config import api_key
import time
import pprint as pprint
url = "https://www.diecastmodelaircraft.com/db/model/"
api_key="#.XCepzVxKiUl"
from bs4 import BeautifulSoup as bs
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)
db=client['DIMA']
colmodels=db['models']
cloudM = "arinmuk"
cloudMpassword = "amarji123!"
cloudMClnt=MongoClient("mongodb+srv://"+ cloudM + ":"
                       + cloudMpassword + "@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority")
clouddb=cloudMClnt['DIMA']
cloudmodels=db['models']

# %%
for i in range(1,2):#77251):
    strng=url+str(i)+api_key
    print(strng)
    response=requests.get(strng)#.xml()
    #print(requests.get(strng))
    #pprint.pprint(response)
    print(response)
    soup = bs(response.text, 'html.parser')
    #type(soup)
    #print(soup.prettify())
    #title=soup.title.text
    #print(title)
# Out:
# https://www.diecastmodelaircraft.com/db/model/1#.XCepzVxKiUl
# <Response [200]>

# %%
tds = soup.find_all('td')

# %%
results = soup.find_all('div')#,class_="align=")
print(results)
# Out:
# [<div class="b-top-menu__background b-top-menu__background--sitebuilder js-top-menu-sitebuilder h-hide-on-small h-hide">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list js-shrink-event-parent">
# </ul>
# </div>
# </div>, <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list js-shrink-event-parent">
# </ul>
# </div>, <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--user js-top-menu-user--list js-shrink-event-parent">
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content b-comp-menu-dropdown__content--right">
# </ul>
# </ul></div>, <div class="noselect h-clearfix h-hide-on-small" id="sitebuilder-wrapper">
# </div>, <div class="main-navbar-bottom-line"></div>, <div id="outer-wrapper">
# <div id="wrapper">
# ...

# %%
import time
data={}
lst=[]
master_lst=[]
for i in range(76986,76989):#77251):#11340#58889#58914#64490;66904;66905;71144;72682;72683;76485,76845:76967;76981,76982,76983,76984,76985
    strng=url+str(i)+api_key
    print(strng)
    response=requests.get(strng)#.xml()
    #print(requests.get(strng))
    #pprint.pprint(response)
    print(response)
    soup = bs(response.text, 'html.parser')
    
    results = soup.find_all('td')#,class_="align=")
    #print(results)
    #time.sleep(3)
    for result in results:
        #print(result.text)
        lst.append(result.text.strip())
        lst=list(filter(None,lst))
        #lst
        #print(len(lst))
    for i in range (0,30-1,2):
        #print(i)
        try:
            data[lst[i].strip(":.,")]=lst[i+1]
            flag='f'
        except:
            print("An exception occurred")
            flag='t'

    #data 
    #master_lst.append(data)
    if len(data) > 0 and flag =='f' :
        print(data)
        print(len(data))
        clouddb.models.insert_one(data)
    data={}
    lst=[]
# Out:
# https://www.diecastmodelaircraft.com/db/model/76986#.XCepzVxKiUl
# <Response [200]>
# {'Manufacturer': 'Realtoy', 'Make/Model': 'Airbus Industries A319', 'Airline': 'Spirit Airlines', 'Scale': '1:400', 'Part #': 'RT3874', 'DiMA ID #': '76986', 'Registration': 'Engines:', 'NA': 'Country:', 'United States of America': 'Continent:', 'North America': 'Production:', '2018 - 2018': 'Units Made:', 'Limited': 'Rolling Gears:', 'Yes': 'Includes Stand:', 'No': 'Notes:', 'With Rolling Gears. With Pullback Action': 'Quick Stats:'}
# 15
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-33-587413403982> in <module>
#      35         print(data)
#      36         print(len(data))
# ---> 37         clouddb.models.insert_one(data)
#      38     data={}
#      39     lst=[]
#
# ...

# %%
#migrate from local to global
import pandas as pd
cursor = clouddb.models.find()
# Expand the cursor and construct the DataFrame
df =  pd.DataFrame(list(cursor))
df.head()

# %%
master_lst
# Out:
# [{'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 737-536',
#   'Airline': 'British Airways',
#   'Scale': '1:500',
#   'Part #': '0',
#   'DiMA ID #': '1',
#   'Registration': 'NA',
#   'Engines': '2 CFM56-3C1',
#   'Country': 'Great Britain',
#   'Continent': 'Europe',
#   'Production': '1993 - 1993',
#   'Units Made': '20',
#   'Rolling Gears': 'No',
#   'Includes Stand': 'No',
#   'Notes': '"Landor" Colors.'},
#  {'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 747-436',
#   'Airline': 'British Airways',
#   'Scale': '1:500',
#   'Part #': '500708',
#   'DiMA ID #': '2',
#   'Registration': 'NA',
#   'Engines': '4 RB211-524H2',
#   'Country': 'Great Britain',
#   'Continent': 'Europe',
#   'Production': '1996 - 1997',
#   'Units Made': 'Unlimited',
#   'Rolling Gears': 'No',
#   'Includes Stand': 'No',
#   'Notes': 'Second Version, "Landor" Colors. With Updated Window Line.'},
#  {'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 747-436',
# ...

# %%
results = soup.find_all('td')#,class_="align=")
data={}
lst=[]
master_lst=[]
for result in results:
    #print(result.text)
    #result=result.strip(":")
    lst.append(result.text.strip())
    # Error handling
    #try:
        # Identify and return title of listing
        #title = result.find('span').text
       # print(title)

lst=list(filter(None,lst))
lst
print(len(lst))
for i in range (0,30-1,2):
    #print(i)
    data[lst[i].strip(":")]=lst[i+1]
    

data
#master_lst.append[data]
#data={}
