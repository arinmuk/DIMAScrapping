# %%
# Dependencies
import requests
import json
import html
#from config import api_key
import time
import pprint as pprint
url = "https://www.diecastmodelaircraft.com/db/model/"
api_key="#.XCepzVxKiUl"
from bs4 import BeautifulSoup as bs
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)
db=client['DIMA']
colmodels=db['models']

# %%
for i in range(1,2):#77251):
    strng=url+str(i)+api_key
    print(strng)
    response=requests.get(strng)#.xml()
    #print(requests.get(strng))
    #pprint.pprint(response)
    print(response)
    soup = bs(response.text, 'html.parser')
    #type(soup)
    #print(soup.prettify())
    #title=soup.title.text
    #print(title)
# Out:
# https://www.diecastmodelaircraft.com/db/model/1#.XCepzVxKiUl
# <Response [200]>

# %%
tds = soup.find_all('td')

# %%
results = soup.find_all('div')#,class_="align=")
print(results)
# Out:
# [<div class="b-top-menu__background b-top-menu__background--sitebuilder js-top-menu-sitebuilder h-hide-on-small h-hide">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list js-shrink-event-parent">
# </ul>
# </div>
# </div>, <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list js-shrink-event-parent">
# </ul>
# </div>, <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--user js-top-menu-user--list js-shrink-event-parent">
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content b-comp-menu-dropdown__content--right">
# </ul>
# </ul></div>, <div class="noselect h-clearfix h-hide-on-small" id="sitebuilder-wrapper">
# </div>, <div class="main-navbar-bottom-line"></div>, <div id="outer-wrapper">
# <div id="wrapper">
# <div class="header-edit-box axdnum_1 h-clearfix" id="header-axd" style="position: absolute !important; margin-top: 25px;margin-left: 150px;">
# <div class="axd-container axd-container_header">
# <div class="admin-only">
# </div>
# <div class="axd axd_header">
# <div class="ad_header_inner">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- DIMA Responsive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2116603283" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# </div>
# <div class="axd-container axd-container_header2">
# <div class="admin-only">
# </div>
# <div class="axd axd_header2">
# </div>
# </div>
# </div>
# <header class="b-top-background__header-mainnav-subnav">
# <div class="b-top-background__header-mainnav">
# <div class="noselect" id="header">
# <div class="header-cell">
# <div class="site-logo header-edit-box">
# <a href="https://www.diecastmodelaircraft.com/"><img alt="Logo" data-orig-src="images/misc/vbulletin5_logo.png" src="https://www.diecastmodelaircraft.com/images/misc/vbulletin5_logo.png" title="Powered by vBulletin"/></a>
# </div>
# </div>
# <div class="toolbar">
# <ul class="h-right">
# <li class="search-container">
# <form action="https://www.diecastmodelaircraft.com/search" class="h-left" id="searchForm" method="GET">
# <div class="h-left">
# <div class="search-box h-clearfix">
# <div class="search-term-container">
# <input autocomplete="off" class="search-term b-form-input__input b-form-input__input--shadow" id="q" name="q" placeholder="Search" type="text"/>
# <div class="search-menu-container h-clearfix">
# <div class="vertical-divider-left"></div>
# <div class="b-comp-menu-dropdown js-comp-menu-dropdown b-comp-menu-dropdown--open-on-hover b-comp-menu-dropdown--header-search">
# <div class="b-comp-menu-dropdown__trigger js-comp-menu-dropdown__trigger b-comp-menu-dropdown__trigger--arrow js-button" tabindex="0"></div>
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content">
# <li class="b-comp-menu-dropdown__content-item b-comp-menu-dropdown__content-item--first b-comp-menu-dropdown__content-item--no-hover js-comp-menu-dropdown__content-maintain-menu">
# <div class="searchPopupBody">
# <label><input class="searchFields_title_only" name="searchFields[title_only]" type="checkbox" value="1"/>Search in titles only</label>
# <div class="b-button-group h-margin-top-xs">
# <button class="b-button b-button--primary" id="btnSearch-popup" type="submit">Search</button>
# </div>
# </div>
# <input name="searchJSON" type="hidden" value=""/>
# </li>
# <li class="b-comp-menu-dropdown__content-item js-comp-menu-dropdown__content-maintain-menu">
# <a class="adv-search-btn" href="#" id="btnAdvSearch">Advanced Search</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <button class="search-btn" id="btnSearch" title="Search" type="submit"><span class="b-icon b-icon__search"></span></button>
# </div>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </div>
# <nav class="h-clearfix noselect" id="channel-tabbar">
# <ul class="channel-tabbar-list h-left b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-small b-comp-menu-dropdown--inactive js-comp-menu-dropdown__content--main-menu h-hide-on-small js-shrink-event-parent">
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_test" href="https://www.diecastmodelaircraft.com/">Home</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_discuss" href="https://www.diecastmodelaircraft.com/discuss">Discuss</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="current section-item js-shrink-event-child">
# <a class="h-left navbar_database" href="https://database.diecastmodelaircraft.com">Database</a>
# <span class="channel-tabbar-divider"></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_collect" href="collect">Collect</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_trade" href="db/tradesearch">Trades</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_want" href="db/wantsearch">Wanted</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_airport" href="https://www.diecastmodelaircraft.com/airports">Airport</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_members" href="memberlist">Members</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_shop" href="https://www.diecastmodelaircraft.com/shop">Shop</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_register" href="https://www.diecastmodelaircraft.com/register">Register</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_contact" href="https://www.diecastmodelaircraft.com/contact-us">Contact</a>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# </ul>
# </nav>
# </div>
# <nav class="h-clearfix h-hide-on-small h-block js-channel-subtabbar" id="channel-subtabbar">
# <ul class="h-left channel-subtabbar-list js-channel-subtabbar-list js-shrink-event-parent">
# <li class="js-shrink-event-child"><a href="/newest">Newest Models</a></li>
# <li class="js-shrink-event-child"><a href="/toplist">Top Models List</a></li>
# <li class="js-shrink-event-child"><a href="/1:200">1:200</a></li>
# <li class="js-shrink-event-child"><a href="/1:400">1:400</a></li>
# <li class="js-shrink-event-child"><a href="/1:500">1:500</a></li>
# <li class="js-shrink-event-child"><a href="/1:600">1:600</a></li>
# <li class="js-shrink-event-child"><a href="/AeroClassics">AeroClassics</a></li>
# <li class="js-shrink-event-child"><a href="/dragon">Dragon Wings</a></li>
# <li class="js-shrink-event-child"><a href="/GeminiJets">GeminiJets</a></li>
# <li class="js-shrink-event-child"><a href="/Herpa">Herpa</a></li>
# <li class="js-shrink-event-child"><a href="/Hogan">Hogan</a></li>
# <li class="js-shrink-event-child"><a href="/Inflight">Inflight</a></li>
# <li class="js-shrink-event-child"><a href="/JCWings">JCWings</a></li>
# <li class="js-shrink-event-child"><a href="/Phoenix">Phoenix</a></li>
# </ul>
# </nav>
# </header>
# <main id="content">
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <title>Herpa 1:500 British Airways B 737-536 0 Diecast Airplane | DiecastModelAircraft.com</title>
# <meta content="Details and photos for Herpa's 1:500 scale diecast aircraft model of a British Airways B 737-536. Herpa part# 0" name="description"/>
# <meta content="Herpa,1:500,British Airways,B 737-536,0,diecast,die cast,model,aircraft,database,airplane,scale" name="keywords"/>
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.1" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.2" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.3" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <script language="JavaScript">
# <!--
# function autoResize(id){
#     var newheight;
#     var newwidth;
#
#     if(document.getElementById){
#         newheight=document.getElementById(id).contentWindow.document .body.scrollHeight;
#         newwidth=document.getElementById(id).contentWindow.document .body.scrollWidth;
#     }
#     if(newheight<50)
#        { document.getElementById(id).height= "25px";
# 	document.getElementById(id).scrolling= "no"; }
#     if(newheight>300)
# 	{ document.getElementById(id).height= "300px";	}
# 	else { 	document.getElementById(id).height= (newheight) + "px"; }
# }
# //-->
# </script>
#
# <div class="tabs settingsTabs ui-tabs underline-tabs-container ui-widget ui-corner-all" style="padding-bottom: 5px !important; border-bottom: 1px solid #AAAAAA;">
# <a href="/search" id="userSettingsProfile" style="cursor: pointer !important;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="background:#EEEEEE">Quick Search</span></a>
# <a href="/advanced?3574" id="userSettingsAccount" style="cursor: pointer !important;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="vertical-align:3px;">Advanced Search</span></a>
# <a href="#" id="userSettingsAccount" style="cursor: pointer;">
# <img src="/images/icons/info.png"/>
# <span class="label" style="vertical-align:3px;"><b>Model Details</b></span></a>
# </div>
# <div class="canvas-layout-container"><!-- END: header -->
# <div class="canvas-layout row-fluid interconnected-widgets private-message-widget-layout" data-layout-id="4" id="canvas-layout-30-70">
# <!-- section 0, 1 -->
# <div class="canvas-layout-row has-columns" style="display: inline;">
# <div class="canvas-widget-list section-0 has-adjacent-right-col span4" style="width: 175px !important;">
# <!-- BEGIN: widget_privatemessage_navigation -->
# <div class="canvas-widget default-widget private-message-widget widget-no-header widget-no-border left-nav" data-widget-id="184" data-widget-instance-id="" style="border-right: 1px solid #C9CED2; border-left: 1px solid #C9CED2; border-bottom: 1px solid #C9CED2; margin-left: -1px;">
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message Navigation<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# <span class="edit-button module-button-item" title="Edit module"><span>Edit</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="widget-content">
# <div class="sb-dialog stretch" id="pmInfoDialogNav">
# <div class="dialog-content stretch" id="pmInfoContentNav">
# </div>
# <div class="action-buttons">
# <button class="button primary" id="pmInfoCloseNav" type="button">Close</button>
# </div>
# </div>
# <div class="clearfix" id="privateMessageNavContainer">
# <div class="nav-pane" style="background: #F4f4f4; padding-top:10px;">
# <center>
# <img class="imgbox" src="http://database.diecastmodelaircraft.com/images/scales/1500.png" style="vertical-align:middle !important;"/><br/>Scale
#
# <p><img alt="Herpa" class="imgbox" nopin="nopin" src="https:/images/manuf/herpawings.gif"/><br/>Herpa
# <p><img alt="British Airways" class="imgbox" src="/logo.3574.gif"/><br/>British Airways
#
# <p><img alt="Great Britain" border="1" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/images/flags/GB.gif"/><br/><font face="Arial" size="1" style="font-size: 10pt">Great Britain</font>
# <p><img align="absmiddle" alt="Europe" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/continents/europe.png"/><br/><font face="Arial" size="1" style="font-size: 10pt">Europe
#
# 				</font></p></p></p></p></center>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <!--Inbox-->
# <div class="folder-item special-folder inbox">
# <a class="selected" href="/collect">
# <span class="label ellipsis" style="margin-left:25px;">Your Collection</span>
# </a>
# </div>
# <iframe height="100" marginheight="4" marginwidth="4" scrolling="no" src="/iframe/modelinfo-collect.php?id=1" style="border: 1;" width="160"></iframe>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:35px;">Model Value</span>
# </a>
# </div>
# <iframe height="50" marginheight="4" marginwidth="4" scrolling="no" src="/iframe/value.php?id=1" style="border: 1;" width="160"></iframe>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:21px;">Model Popularity</span>
# </a>
# </div>
# <html>
# <head>
# <script src="/RGraph/libraries/RGraph.common.core.js"></script>
# <script src="/RGraph/libraries/RGraph.common.dynamic.js"></script>
# <script src="/RGraph/libraries/RGraph.meter.js"></script>
# <!--[if lt IE 9]><script src="/RGraph/excanvas/excanvas.js"></script><![endif]-->
# </head>
# <body>
# <canvas height="100" id="cvs" style="border: 0px solid #ccc" width="172">[No canvas support]</canvas>
# <script>
#         window.onload = function ()
#         {
#             var meter = new RGraph.Meter('cvs', 0,100,0);
#             meter.Set('angles.start', PI - 0.0);
#             meter.Set('angles.end', TWOPI + 0.0);
#             meter.Set('linewidth.segments', 10);
#             meter.Set('text.size', 9);
#             meter.Set('strokestyle', 'white');
#             meter.Set('segment.radius.start', 0);
#             meter.Set('chart.border', 0);
#             meter.Set('tickmarks.small.num', 0);
#             meter.Set('tickmarks.big.num', 0);
# 	    meter.Set('chart.needle.radius', 50);
#             meter.Set('chart.needle.linewidth', 1);
#     	    meter.Set('chart.red.color', '#D20707');
#     	    meter.Set('chart.red.start', 10);
#     	    meter.Set('chart.red.end', 40);
#     	    meter.Set('chart.yellow.color', '#FFD104');
#     	    meter.Set('chart.yellow.start', 40)
#     	    meter.Set('chart.yellow.end', 75);
#     	    meter.Set('chart.green.color', '#3B7F3B');
#     	    meter.Set('chart.green.start', 75);
# 	meter.Set('chart.shadow',1);
# 	meter.Set('chart.shadow.color','#e5e5e5');
# 	meter.Set('chart.shadow.blur',15);
# 	meter.Set('chart.shadow.offsetx',0);
# 	meter.Set('chart.shadow.offsety',10);
#             meter.Draw();
#
#
#         }
#     </script>
# <br/>
# <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; margin-left:10px !important; font-size:13px;">
# Popularity Score:
# </span></a>
# <span class="databox" style="font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/collectors/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Collected:
# </span></a><span class="databox">
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/buyers/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Wanted:
# </span></a><span class="databox">
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/trades/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Trading:
# </span></a><span class="databox">
# 0</span></div>
# </body></html></div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <!--Inbox-->
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:45px;">Model Size</span>
# </a>
# </div>
# <!--Messages-->
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Length: 6.20cm / 2.42"</font>
# </span>
# </a>
# </div>
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Wingspan: 5.78cm / 2.25"</font>
# </span>
# </a>
# </div>
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Height: 2.23cm / 0.87"</font></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- END: widget_privatemessage_navigation -->
# </div><div class="canvas-widget-list section-1 has-adjacent-left-col span8" style="padding-left: 176px !important;">
# <!-- BEGIN: widget_privatemessage_toolbar -->
# <div class="canvas-widget default-widget private-message-widget widget-no-header widget-no-border private-message-toolbar empty" data-widget-id="186" data-widget-instance-id="" style="padding-top: 7px; background: #F4f4f4 !important; padding-bottom: 8px; margin-bottom:0px; border-bottom: 1px solid #C9CED2;">
# <center><span style="font-size: 16px !important;">Herpa British Airways B 737-536 1:500</span>
# </center></div>
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message Toolbar<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="canvas-widget default-widget private-message-widget conversation-content-widget widget-no-header widget-no-border private-message-display" data-widget-id="182" data-widget-instance-id="">
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="widget-content" style="width: 80% !important; border-right: solid 1px #C8CCCE">
# <div class="sb-dialog" id="pmInfoDialog">
# <div class="dialog-content" id="pmInfoContent"></div>
# </div>
# <div class="clearfix" id="privateMessageContainer">
# <div class="main-pane clearfix">
# <!-- BEGIN: privatemessage_foldersummary --><div class="main-pane-container">
# <center><br/>
# <table border="0" cellpadding="0" cellspacing="0" style="border-color: #FFFFFF; border: solid 0px;  border-collapse:collapse;" width="95%">
# <tr>
# <td ;="" align="right" bgcolor="#F4F4F4"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Manufacturer:</font></td>
# <td><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt"><span><a href="/manufacturer/Herpa">Herpa</a></span></font></td>
# <td align="right" bgcolor="#F4F4F4"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Make/Model:</font></td>
# <td><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt"><span>Boeing B 737-536</span></font></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Airline:</font></b>
# </td><td>British Airways</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Scale:</font></b></td>
# <td>1:500</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Part #:</font></b></td>
# <td><span class="purplemed"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt">0</font></span></td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">DiMA ID #:</font></b></td>
# <td><span class="purplemed"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt">1</font></span></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Registration:</font></td>
# <td><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt"><span>NA</span></font></td>
# <td align="right" bgcolor="#F4F4F4"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Engines:</font></td>
# <td><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt"><span>2 CFM56-3C1</span></font></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">
#                                                 Country:</font></td>
# <td><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt">
# <span>Great Britain</span></font></td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Continent:</font></b></td>
# <td><span class="purplemed"><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt">Europe</font></span></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Production:</font></b></td>
# <td>1993 - 1993</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Units Made:</font></b></td>
# <td>20</td>
# </tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Rolling Gears:</font></b></td>
# <td>No</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Includes Stand:</font></b></td>
# <td>No</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td><tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Notes:</font></b></td>
# <td colspan="4">"Landor" Colors.</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td><tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial"="" face="" open="" sans",="" size="1" style="font-size: 10pt; font-weight:700">Quick Stats:</font></b></td>
# <td colspan="4">
# <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; font-size:13px;">
# Popularity Score:</span></a>
# <span class="databox" style="position: relative;left: 2px;width: 15px; font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span>
# <span style="padding-left: 10px;">
# Collectors <a href="/collectors/1">(0)</a>
# Buyers <a href="/buyers/1">(0)</a>
# Traders <a href="/trades-available/1">(0)</a>
# </span>
# </div>
# </td></tr>
# </tr></tr></table>
# <h2 class="main-pane-header" style="width: 713px;"><center><span font-size:14px;"="" open="" sans","open="" sans",arial;="" style="font-family: "><b>Model Photos</b></span></center></h2>
# <iframe frameborder="0" height="515" scrolling="no" src="/iframe/galleria.php?mid=1" width="100%"></iframe>
# <a class="variousedit" data-fancybox-type="iframe" href="https://www.wafflecollectibles.com/custom/upload.php?id=1&amp;bbuserid=&amp;bbusername=" title="Upload a Photo of this model"><img src="/images/icons/upload.png"/>
# Upload a photo of this model!</a>
# </center></div>
# <!-- END: privatemessage_foldersummary -->
# </div>
# </div>
# </div>
# <!-- Right space begin -->
# <div class="widget-content" style="width: 275px !important; border: solid 0px; display:inline; position: absolute;">
# <center>
# <table style="border: dashed 1px #b4b4b4; margin-top:0px;">
# <tr>
# <td align="center" style="cursor: pointer">
# <img src="https://www.ebayadservices.com/marketingtracking/v1/impression?mpt=[CACHEBUSTER]&amp;mkcid=1&amp;mkrid=711-53200-19255-0&amp;mkevt=2&amp;siteid=0&amp;campid=5337235573&amp;ad_type=0&amp;toolid=10001" style="text-decoration:none;border:0;padding:0;margin:0;"/>
# <a href="
# https://www.ebay.com/sch/i.html?_from=R40&amp;_trksid=p2380057.m570.l1313&amp;_nkw=
# %28Herpa,%20British+Airways,%20737%29+%28%29
# &amp;_sacat=0&amp;mkrid=711-53200-19255-0&amp;siteid=0&amp;mkcid=1&amp;campid=
# 5337235573
# &amp;toolid=10001&amp;customid=&amp;mkevt=1
# " target="_blank">
# <img src="/ebaystatus/%28Herpa,%20British+Airways,%20737%29+%28%29/1"/></a>
# </td></tr>
# <tr><td align="center">Retailers &amp; Trades</td></tr>
# <tr><td align="center">
# <a href="/availability/1"><img src="/stock/1" style="margin-top:5px;"/></a>
# 			<a href="/trades/1"><img src="/trades/1" style="margin-top:5px;"/></a>
# </td></tr>
# </table>
# <table><tr><td>
# <span style="font-size:12px !important;">You can use these links throughout to help manage your collection and want list:
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/aircraft.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Got it!</b> - Use these to add this model to your online collection!<br/>
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/heart.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Want it!</b> - Add the model to your Want list, and we will email you when it is in stock!	<br/>
# <tr><td>
# <p>
# <center>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Right 200x200 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2768462515" style="display:inline-block;width:200px;height:200px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </center>
# </p></td></tr>
# </span></td></tr></table>
# <!-- BEGIN: footer --></center></div>
# <br/>
# <table width="100%%"><tr><td align="left" width="550">
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	This model and others on <img nopin="nopin" src="/images/ebay_logo.png" valign="absmiddle"/>
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/rss.php?search=%28Herpa,%20British Airways,%20B 737-536%29%20%280%29&amp;search2=%28Herpa,%20British Airways%29" width="100%"></iframe>
# </div></div>
# </td><td>
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Value Graphs
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <center><table align="center" style="margin-bottom: 0px !important;"><tr><td>
# <iframe height="350" scrolling="no" src="/iframe/avggraph.php?mid=1" width="470"></iframe>
# </td></tr></table>
# </center></div>
# </div>
# </td></tr></table></div>
#
# <table width="100%%"><tr><td align="left" width="550">
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	Retailer Availability
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/availability-list-narrow.php?mid=1" width="100%"></iframe>
# </div></div>
# </td><td>
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Collectors of this Model
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="220" src="/iframe/collectors.php?mid=1" width="100%"></iframe>
# </div>
# </div>
# </td></tr></table></div>
#
# <p><center>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script> <!-- DIMA Responsive --> <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2116603283" style="display:inline-block;width:728px;height:90px"></ins> <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <footer id="footer">
# <nav class="h-clearfix js-shrink-event-parent" id="footer-tabbar">
# <ul class="h-left js-footer-chooser-list h-margin-left-xxl js-shrink-event-child">
# </ul>
# <ul class="nav-list h-right js-footer-nav-list h-margin-right-xxl b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-xsmall b-comp-menu-dropdown--inactive js-shrink-event-child" data-dropdown-menu-classes="h-margin-vert-l b-comp-menu-dropdown--direction-up" data-dropdown-trigger-classes="b-comp-menu-dropdown__trigger--arrow" data-dropdown-trigger-phrase="go_to_ellipsis">
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/help">Help</a>
# </li>
# <li class="current">
# <a href="https://www.diecastmodelaircraft.com/">Home</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/discuss">Discuss</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/db">Database</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/collect">Collect</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/want">Wanted</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/shop">Shop</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/memberlist">Member List</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/blogs">Blogs</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/social-groups">Groups</a>
# </li>
# <li><a class="js-footer-go-to-top" href="#">Go to top</a></li>
# </ul>
# </nav>
# </footer>
# </center></p></div>
# <div id="footer-copyright">
# <div id="footer-user-copyright">© 2021 DiMA DiecastModelAircraft.com. The website, content,  design and  pictures and are intended for public commercial and non-commercial use of Waffle Collectibles LLC, and may be redistributed, freely printed, or electronically reproduced in its complete and unaltered form provided distribution is for the use of Waffle Collectibles LLC and it's affiliated websites only. Partial and other distribution means require the permission of DiMA &amp; Waffle Collectibles LLC. All rights reserved. Airline Logos are used under license from AirlineLogos.net</div>
# <div id="footer-vb-copyright">Powered by <a href="https://www.vbulletin.com" id="vbulletinlink">vBulletin®</a> Version 5.6.4 <br>Copyright © 2021 MH Sub I, LLC dba vBulletin. All rights reserved. </br></div>
# <div id="footer-current-datetime">All times are GMT-5. This page was generated at 10:21 AM.</div>
# </div>
# </div>
# <div class="js-loading-indicator b-ajax-loading-indicator h-hide" id="loading-indicator">
# <span>Working...</span>
# </div>
# <div class="js-flash-message b-ajax-loading-indicator b-ajax-loading-indicator--medium h-hide">
# <span class="js-flash-message-content"></span>
# </div>
# <div class="sb-dialog" id="confirm-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnConfirmDialogYes" type="button">Yes</button>
# <button class="b-button b-button--secondary js-button" id="btnConfirmDialogNo" type="button">No</button>
# </div>
# </div>
# <div class="sb-dialog" id="alert-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnAlertDialogOK" type="button">OK</button>
# </div>
# </div>
# <div class="sb-dialog" id="prompt-dialog">
# <div class="dialog-content table h-clearfix">
# <div class="message td"></div>
# <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>
# </div>
# <div class="js-prompt-error h-hide"></div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnPromptDialogOK" type="button">OK</button>
# <button class="b-button b-button--secondary js-button" id="btnPromptDialogCancel" type="button">Cancel</button>
# </div>
# </div>
# <div class="sb-dialog slideshow" id="slideshow-dialog">
# <div class="b-icon b-icon__x-square--gray close-btn">X</div>
# <div class="slideshow-wrapper"></div>
# <div class="caption"></div>
# <div class="thumbnails-wrapper">
# <div class="thumbnails"></div>
# </div>
# </div>
# <div class="unsubscribe-overlay-container"></div>
# <div data-facebook-language="en_US" id="fb-root"></div>
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-8194867-14', 'auto');
#   ga('send', 'pageview');
# </script>
# </main></div></div>, <div id="wrapper">
# <div class="header-edit-box axdnum_1 h-clearfix" id="header-axd" style="position: absolute !important; margin-top: 25px;margin-left: 150px;">
# <div class="axd-container axd-container_header">
# <div class="admin-only">
# </div>
# <div class="axd axd_header">
# <div class="ad_header_inner">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- DIMA Responsive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2116603283" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# </div>
# <div class="axd-container axd-container_header2">
# <div class="admin-only">
# </div>
# <div class="axd axd_header2">
# </div>
# </div>
# </div>
# <header class="b-top-background__header-mainnav-subnav">
# <div class="b-top-background__header-mainnav">
# <div class="noselect" id="header">
# <div class="header-cell">
# <div class="site-logo header-edit-box">
# <a href="https://www.diecastmodelaircraft.com/"><img alt="Logo" data-orig-src="images/misc/vbulletin5_logo.png" src="https://www.diecastmodelaircraft.com/images/misc/vbulletin5_logo.png" title="Powered by vBulletin"/></a>
# </div>
# </div>
# <div class="toolbar">
# <ul class="h-right">
# <li class="search-container">
# <form action="https://www.diecastmodelaircraft.com/search" class="h-left" id="searchForm" method="GET">
# <div class="h-left">
# <div class="search-box h-clearfix">
# <div class="search-term-container">
# <input autocomplete="off" class="search-term b-form-input__input b-form-input__input--shadow" id="q" name="q" placeholder="Search" type="text"/>
# <div class="search-menu-container h-clearfix">
# <div class="vertical-divider-left"></div>
# <div class="b-comp-menu-dropdown js-comp-menu-dropdown b-comp-menu-dropdown--open-on-hover b-comp-menu-dropdown--header-search">
# <div class="b-comp-menu-dropdown__trigger js-comp-menu-dropdown__trigger b-comp-menu-dropdown__trigger--arrow js-button" tabindex="0"></div>
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content">
# <li class="b-comp-menu-dropdown__content-item b-comp-menu-dropdown__content-item--first b-comp-menu-dropdown__content-item--no-hover js-comp-menu-dropdown__content-maintain-menu">
# <div class="searchPopupBody">
# <label><input class="searchFields_title_only" name="searchFields[title_only]" type="checkbox" value="1"/>Search in titles only</label>
# <div class="b-button-group h-margin-top-xs">
# <button class="b-button b-button--primary" id="btnSearch-popup" type="submit">Search</button>
# </div>
# </div>
# <input name="searchJSON" type="hidden" value=""/>
# </li>
# <li class="b-comp-menu-dropdown__content-item js-comp-menu-dropdown__content-maintain-menu">
# <a class="adv-search-btn" href="#" id="btnAdvSearch">Advanced Search</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <button class="search-btn" id="btnSearch" title="Search" type="submit"><span class="b-icon b-icon__search"></span></button>
# </div>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </div>
# <nav class="h-clearfix noselect" id="channel-tabbar">
# <ul class="channel-tabbar-list h-left b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-small b-comp-menu-dropdown--inactive js-comp-menu-dropdown__content--main-menu h-hide-on-small js-shrink-event-parent">
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_test" href="https://www.diecastmodelaircraft.com/">Home</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_discuss" href="https://www.diecastmodelaircraft.com/discuss">Discuss</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="current section-item js-shrink-event-child">
# <a class="h-left navbar_database" href="https://database.diecastmodelaircraft.com">Database</a>
# <span class="channel-tabbar-divider"></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_collect" href="collect">Collect</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_trade" href="db/tradesearch">Trades</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_want" href="db/wantsearch">Wanted</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_airport" href="https://www.diecastmodelaircraft.com/airports">Airport</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_members" href="memberlist">Members</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_shop" href="https://www.diecastmodelaircraft.com/shop">Shop</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_register" href="https://www.diecastmodelaircraft.com/register">Register</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_contact" href="https://www.diecastmodelaircraft.com/contact-us">Contact</a>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# </ul>
# </nav>
# </div>
# <nav class="h-clearfix h-hide-on-small h-block js-channel-subtabbar" id="channel-subtabbar">
# <ul class="h-left channel-subtabbar-list js-channel-subtabbar-list js-shrink-event-parent">
# <li class="js-shrink-event-child"><a href="/newest">Newest Models</a></li>
# <li class="js-shrink-event-child"><a href="/toplist">Top Models List</a></li>
# <li class="js-shrink-event-child"><a href="/1:200">1:200</a></li>
# <li class="js-shrink-event-child"><a href="/1:400">1:400</a></li>
# <li class="js-shrink-event-child"><a href="/1:500">1:500</a></li>
# <li class="js-shrink-event-child"><a href="/1:600">1:600</a></li>
# <li class="js-shrink-event-child"><a href="/AeroClassics">AeroClassics</a></li>
# <li class="js-shrink-event-child"><a href="/dragon">Dragon Wings</a></li>
# <li class="js-shrink-event-child"><a href="/GeminiJets">GeminiJets</a></li>
# <li class="js-shrink-event-child"><a href="/Herpa">Herpa</a></li>
# <li class="js-shrink-event-child"><a href="/Hogan">Hogan</a></li>
# <li class="js-shrink-event-child"><a href="/Inflight">Inflight</a></li>
# <li class="js-shrink-event-child"><a href="/JCWings">JCWings</a></li>
# <li class="js-shrink-event-child"><a href="/Phoenix">Phoenix</a></li>
# </ul>
# </nav>
# </header>
# <main id="content">
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <title>Herpa 1:500 British Airways B 737-536 0 Diecast Airplane | DiecastModelAircraft.com</title>
# <meta content="Details and photos for Herpa's 1:500 scale diecast aircraft model of a British Airways B 737-536. Herpa part# 0" name="description"/>
# <meta content="Herpa,1:500,British Airways,B 737-536,0,diecast,die cast,model,aircraft,database,airplane,scale" name="keywords"/>
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.1" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.2" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.3" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <script language="JavaScript">
# <!--
# function autoResize(id){
#     var newheight;
#     var newwidth;
#
#     if(document.getElementById){
#         newheight=document.getElementById(id).contentWindow.document .body.scrollHeight;
#         newwidth=document.getElementById(id).contentWindow.document .body.scrollWidth;
#     }
#     if(newheight<50)
#        { document.getElementById(id).height= "25px";
# 	document.getElementById(id).scrolling= "no"; }
#     if(newheight>300)
# 	{ document.getElementById(id).height= "300px";	}
# 	else { 	document.getElementById(id).height= (newheight) + "px"; }
# }
# //-->
# </script>
#
# <div class="tabs settingsTabs ui-tabs underline-tabs-container ui-widget ui-corner-all" style="padding-bottom: 5px !important; border-bottom: 1px solid #AAAAAA;">
# <a href="/search" id="userSettingsProfile" style="cursor: pointer !important;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="background:#EEEEEE">Quick Search</span></a>
# <a href="/advanced?3574" id="userSettingsAccount" style="cursor: pointer !important;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="vertical-align:3px;">Advanced Search</span></a>
# <a href="#" id="userSettingsAccount" style="cursor: pointer;">
# <img src="/images/icons/info.png"/>
# <span class="label" style="vertical-align:3px;"><b>Model Details</b></span></a>
# </div>
# <div class="canvas-layout-container"><!-- END: header -->
# <div class="canvas-layout row-fluid interconnected-widgets private-message-widget-layout" data-layout-id="4" id="canvas-layout-30-70">
# <!-- section 0, 1 -->
# <div class="canvas-layout-row has-columns" style="display: inline;">
# <div class="canvas-widget-list section-0 has-adjacent-right-col span4" style="width: 175px !important;">
# <!-- BEGIN: widget_privatemessage_navigation -->
# <div class="canvas-widget default-widget private-message-widget widget-no-header widget-no-border left-nav" data-widget-id="184" data-widget-instance-id="" style="border-right: 1px solid #C9CED2; border-left: 1px solid #C9CED2; border-bottom: 1px solid #C9CED2; margin-left: -1px;">
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message Navigation<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# <span class="edit-button module-button-item" title="Edit module"><span>Edit</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="widget-content">
# <div class="sb-dialog stretch" id="pmInfoDialogNav">
# <div class="dialog-content stretch" id="pmInfoContentNav">
# </div>
# <div class="action-buttons">
# <button class="button primary" id="pmInfoCloseNav" type="button">Close</button>
# </div>
# </div>
# <div class="clearfix" id="privateMessageNavContainer">
# <div class="nav-pane" style="background: #F4f4f4; padding-top:10px;">
# <center>
# <img class="imgbox" src="http://database.diecastmodelaircraft.com/images/scales/1500.png" style="vertical-align:middle !important;"/><br/>Scale
#
# <p><img alt="Herpa" class="imgbox" nopin="nopin" src="https:/images/manuf/herpawings.gif"/><br/>Herpa
# <p><img alt="British Airways" class="imgbox" src="/logo.3574.gif"/><br/>British Airways
#
# <p><img alt="Great Britain" border="1" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/images/flags/GB.gif"/><br/><font face="Arial" size="1" style="font-size: 10pt">Great Britain</font>
# <p><img align="absmiddle" alt="Europe" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/continents/europe.png"/><br/><font face="Arial" size="1" style="font-size: 10pt">Europe
#
# 				</font></p></p></p></p></center>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <!--Inbox-->
# <div class="folder-item special-folder inbox">
# <a class="selected" href="/collect">
# <span class="label ellipsis" style="margin-left:25px;">Your Collection</span>
# </a>
# </div>
# <iframe height="100" marginheight="4" marginwidth="4" scrolling="no" src="/iframe/modelinfo-collect.php?id=1" style="border: 1;" width="160"></iframe>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# ...
# <td colspan="4">
# <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; font-size:13px;">
# Popularity Score:</span></a>
# <span class="databox" style="position: relative;left: 2px;width: 15px; font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span>
# <span style="padding-left: 10px;">
# Collectors <a href="/collectors/1">(0)</a>
# Buyers <a href="/buyers/1">(0)</a>
# Traders <a href="/trades-available/1">(0)</a>
# </span>
# </div>
# </td></tr>
# </tr></tr></table>
# <h2 class="main-pane-header" style="width: 713px;"><center><span font-size:14px;"="" open="" sans","open="" sans",arial;="" style="font-family: "><b>Model Photos</b></span></center></h2>
# <iframe frameborder="0" height="515" scrolling="no" src="/iframe/galleria.php?mid=1" width="100%"></iframe>
# <a class="variousedit" data-fancybox-type="iframe" href="https://www.wafflecollectibles.com/custom/upload.php?id=1&amp;bbuserid=&amp;bbusername=" title="Upload a Photo of this model"><img src="/images/icons/upload.png"/>
# Upload a photo of this model!</a>
# </center></div>, <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; font-size:13px;">
# Popularity Score:</span></a>
# <span class="databox" style="position: relative;left: 2px;width: 15px; font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span>
# <span style="padding-left: 10px;">
# Collectors <a href="/collectors/1">(0)</a>
# Buyers <a href="/buyers/1">(0)</a>
# Traders <a href="/trades-available/1">(0)</a>
# </span>
# </div>, <div class="widget-content" style="width: 275px !important; border: solid 0px; display:inline; position: absolute;">
# <center>
# <table style="border: dashed 1px #b4b4b4; margin-top:0px;">
# <tr>
# <td align="center" style="cursor: pointer">
# <img src="https://www.ebayadservices.com/marketingtracking/v1/impression?mpt=[CACHEBUSTER]&amp;mkcid=1&amp;mkrid=711-53200-19255-0&amp;mkevt=2&amp;siteid=0&amp;campid=5337235573&amp;ad_type=0&amp;toolid=10001" style="text-decoration:none;border:0;padding:0;margin:0;"/>
# <a href="
# https://www.ebay.com/sch/i.html?_from=R40&amp;_trksid=p2380057.m570.l1313&amp;_nkw=
# %28Herpa,%20British+Airways,%20737%29+%28%29
# &amp;_sacat=0&amp;mkrid=711-53200-19255-0&amp;siteid=0&amp;mkcid=1&amp;campid=
# 5337235573
# &amp;toolid=10001&amp;customid=&amp;mkevt=1
# " target="_blank">
# <img src="/ebaystatus/%28Herpa,%20British+Airways,%20737%29+%28%29/1"/></a>
# </td></tr>
# <tr><td align="center">Retailers &amp; Trades</td></tr>
# <tr><td align="center">
# <a href="/availability/1"><img src="/stock/1" style="margin-top:5px;"/></a>
# 			<a href="/trades/1"><img src="/trades/1" style="margin-top:5px;"/></a>
# </td></tr>
# </table>
# <table><tr><td>
# <span style="font-size:12px !important;">You can use these links throughout to help manage your collection and want list:
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/aircraft.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Got it!</b> - Use these to add this model to your online collection!<br/>
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/heart.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Want it!</b> - Add the model to your Want list, and we will email you when it is in stock!	<br/>
# <tr><td>
# <p>
# <center>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Right 200x200 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2768462515" style="display:inline-block;width:200px;height:200px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </center>
# </p></td></tr>
# </span></td></tr></table>
# <!-- BEGIN: footer --></center></div>, <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	This model and others on <img nopin="nopin" src="/images/ebay_logo.png" valign="absmiddle"/>
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/rss.php?search=%28Herpa,%20British Airways,%20B 737-536%29%20%280%29&amp;search2=%28Herpa,%20British Airways%29" width="100%"></iframe>
# </div></div>, <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	This model and others on <img nopin="nopin" src="/images/ebay_logo.png" valign="absmiddle"/>
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>, <div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	This model and others on <img nopin="nopin" src="/images/ebay_logo.png" valign="absmiddle"/>
# </span></div>, <div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div>, <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/rss.php?search=%28Herpa,%20British Airways,%20B 737-536%29%20%280%29&amp;search2=%28Herpa,%20British Airways%29" width="100%"></iframe>
# </div>, <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Value Graphs
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <center><table align="center" style="margin-bottom: 0px !important;"><tr><td>
# <iframe height="350" scrolling="no" src="/iframe/avggraph.php?mid=1" width="470"></iframe>
# </td></tr></table>
# </center></div>
# </div>, <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Value Graphs
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>, <div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Value Graphs
# </span></div>, <div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div>, <div class="widget-content">
# <center><table align="center" style="margin-bottom: 0px !important;"><tr><td>
# <iframe height="350" scrolling="no" src="/iframe/avggraph.php?mid=1" width="470"></iframe>
# </td></tr></table>
# </center></div>, <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	Retailer Availability
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/availability-list-narrow.php?mid=1" width="100%"></iframe>
# </div></div>, <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	Retailer Availability
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>, <div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	Retailer Availability
# </span></div>, <div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div>, <div class="widget-content">
# <iframe height="30" id="iframe1" marginheight="0" src="/iframe/availability-list-narrow.php?mid=1" width="100%"></iframe>
# </div>, <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Collectors of this Model
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="220" src="/iframe/collectors.php?mid=1" width="100%"></iframe>
# </div>
# </div>, <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Collectors of this Model
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>, <div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Collectors of this Model
# </span></div>, <div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div>, <div class="widget-content">
# <iframe height="220" src="/iframe/collectors.php?mid=1" width="100%"></iframe>
# </div>, <div id="footer-copyright">
# <div id="footer-user-copyright">© 2021 DiMA DiecastModelAircraft.com. The website, content,  design and  pictures and are intended for public commercial and non-commercial use of Waffle Collectibles LLC, and may be redistributed, freely printed, or electronically reproduced in its complete and unaltered form provided distribution is for the use of Waffle Collectibles LLC and it's affiliated websites only. Partial and other distribution means require the permission of DiMA &amp; Waffle Collectibles LLC. All rights reserved. Airline Logos are used under license from AirlineLogos.net</div>
# <div id="footer-vb-copyright">Powered by <a href="https://www.vbulletin.com" id="vbulletinlink">vBulletin®</a> Version 5.6.4 <br>Copyright © 2021 MH Sub I, LLC dba vBulletin. All rights reserved. </br></div>
# <div id="footer-current-datetime">All times are GMT-5. This page was generated at 10:21 AM.</div>
# </div>, <div id="footer-user-copyright">© 2021 DiMA DiecastModelAircraft.com. The website, content,  design and  pictures and are intended for public commercial and non-commercial use of Waffle Collectibles LLC, and may be redistributed, freely printed, or electronically reproduced in its complete and unaltered form provided distribution is for the use of Waffle Collectibles LLC and it's affiliated websites only. Partial and other distribution means require the permission of DiMA &amp; Waffle Collectibles LLC. All rights reserved. Airline Logos are used under license from AirlineLogos.net</div>, <div id="footer-vb-copyright">Powered by <a href="https://www.vbulletin.com" id="vbulletinlink">vBulletin®</a> Version 5.6.4 <br>Copyright © 2021 MH Sub I, LLC dba vBulletin. All rights reserved. </br></div>, <div id="footer-current-datetime">All times are GMT-5. This page was generated at 10:21 AM.</div>, <div class="js-loading-indicator b-ajax-loading-indicator h-hide" id="loading-indicator">
# <span>Working...</span>
# </div>, <div class="js-flash-message b-ajax-loading-indicator b-ajax-loading-indicator--medium h-hide">
# <span class="js-flash-message-content"></span>
# </div>, <div class="sb-dialog" id="confirm-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnConfirmDialogYes" type="button">Yes</button>
# <button class="b-button b-button--secondary js-button" id="btnConfirmDialogNo" type="button">No</button>
# </div>
# </div>, <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>, <div class="icon h-left"></div>, <div class="message"></div>, <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnConfirmDialogYes" type="button">Yes</button>
# <button class="b-button b-button--secondary js-button" id="btnConfirmDialogNo" type="button">No</button>
# </div>, <div class="sb-dialog" id="alert-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnAlertDialogOK" type="button">OK</button>
# </div>
# </div>, <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>, <div class="icon h-left"></div>, <div class="message"></div>, <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnAlertDialogOK" type="button">OK</button>
# </div>, <div class="sb-dialog" id="prompt-dialog">
# <div class="dialog-content table h-clearfix">
# <div class="message td"></div>
# <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>
# </div>
# <div class="js-prompt-error h-hide"></div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnPromptDialogOK" type="button">OK</button>
# <button class="b-button b-button--secondary js-button" id="btnPromptDialogCancel" type="button">Cancel</button>
# </div>
# </div>, <div class="dialog-content table h-clearfix">
# <div class="message td"></div>
# <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>
# </div>, <div class="message td"></div>, <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>, <div class="js-prompt-error h-hide"></div>, <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnPromptDialogOK" type="button">OK</button>
# <button class="b-button b-button--secondary js-button" id="btnPromptDialogCancel" type="button">Cancel</button>
# </div>, <div class="sb-dialog slideshow" id="slideshow-dialog">
# <div class="b-icon b-icon__x-square--gray close-btn">X</div>
# <div class="slideshow-wrapper"></div>
# <div class="caption"></div>
# <div class="thumbnails-wrapper">
# <div class="thumbnails"></div>
# </div>
# </div>, <div class="b-icon b-icon__x-square--gray close-btn">X</div>, <div class="slideshow-wrapper"></div>, <div class="caption"></div>, <div class="thumbnails-wrapper">
# <div class="thumbnails"></div>
# </div>, <div class="thumbnails"></div>, <div class="unsubscribe-overlay-container"></div>, <div data-facebook-language="en_US" id="fb-root"></div>]

# %%
import time
data={}
lst=[]
master_lst=[]
for i in range(6100,7000):#77251):
    strng=url+str(i)+api_key
    print(strng)
    response=requests.get(strng)#.xml()
    #print(requests.get(strng))
    #pprint.pprint(response)
    print(response)
    soup = bs(response.text, 'html.parser')
    
    results = soup.find_all('td')#,class_="align=")
    #print(results)
    #time.sleep(3)
    for result in results:
        #print(result.text)
        lst.append(result.text.strip())
        lst=list(filter(None,lst))
        #lst
        #print(len(lst))
    for i in range (0,30-1,2):
        #print(i)
        try:
            data[lst[i].strip(":.")]=lst[i+1]
        except:
              print("An exception occurred")

    #data
    #master_lst.append(data)
    if len(data) > 0:
        db.models.insert_one(data)
    data={}
    lst=[]
# Out:
# https://www.diecastmodelaircraft.com/db/model/6100#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6101#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6102#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6103#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6104#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6105#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6106#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6107#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6108#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6109#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6110#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6111#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6112#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6113#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6114#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6115#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6116#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6117#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6118#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6119#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6120#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6121#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6122#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6123#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6124#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6125#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6126#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6127#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6128#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6129#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6130#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6131#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6132#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6133#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6134#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6135#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6136#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6137#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6138#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6139#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6140#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6141#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6142#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6143#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6144#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6145#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6146#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6147#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6148#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6149#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6150#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6151#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6152#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6153#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6154#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6155#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6156#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6157#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6158#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6159#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6160#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6161#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6162#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6163#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6164#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6165#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6166#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6167#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6168#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6169#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6170#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6171#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6172#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6173#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6174#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6175#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6176#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6177#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6178#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6179#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6180#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6181#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6182#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6183#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6184#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6185#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6186#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6187#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6188#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6189#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6190#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6191#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6192#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6193#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6194#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6195#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6196#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6197#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6198#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6199#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6200#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6201#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6202#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6203#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6204#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6205#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6206#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6207#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6208#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6209#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6210#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6211#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6212#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6213#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6214#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6215#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6216#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6217#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6218#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6219#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6220#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6221#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6222#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6223#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6224#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6225#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6226#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6227#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6228#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6229#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6230#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6231#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6232#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6233#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6234#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6235#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6236#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6237#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6238#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6239#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6240#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6241#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6242#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6243#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6244#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6245#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6246#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6247#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6248#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6249#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6250#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6251#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6252#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6253#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6254#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6255#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6256#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6257#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6258#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6259#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6260#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6261#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6262#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6263#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6264#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6265#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6266#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6267#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6268#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6269#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6270#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6271#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6272#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6273#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6274#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6275#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6276#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6277#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6278#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6279#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6280#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6281#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6282#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6283#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6284#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6285#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6286#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6287#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6288#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6289#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6290#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6291#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6292#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6293#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6294#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6295#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6296#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6297#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6298#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6299#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6300#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6301#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6302#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6303#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6304#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6305#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6306#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6307#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6308#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6309#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6310#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6311#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6312#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6313#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6314#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6315#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6316#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6317#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6318#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6319#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6320#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6321#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6322#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6323#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6324#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6325#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6326#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6327#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6328#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6329#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6330#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6331#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6332#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6333#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6334#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6335#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6336#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6337#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6338#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6339#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6340#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6341#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6342#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6343#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6344#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6345#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6346#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6347#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6348#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6349#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6350#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6351#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6352#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6353#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6354#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6355#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6356#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6357#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6358#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6359#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6360#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6361#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6362#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6363#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6364#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6365#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6366#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6367#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6368#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6369#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6370#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6371#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6372#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6373#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6374#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6375#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6376#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6377#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6378#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6379#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6380#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6381#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6382#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6383#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6384#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6385#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6386#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6387#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6388#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6389#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6390#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6391#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6392#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6393#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6394#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6395#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6396#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6397#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6398#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6399#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6400#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6401#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6402#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6403#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6404#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6405#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6406#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6407#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6408#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6409#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6410#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6411#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6412#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6413#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6414#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6415#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6416#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6417#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6418#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6419#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6420#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6421#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6422#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6423#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6424#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6425#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6426#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6427#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6428#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6429#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6430#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6431#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6432#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6433#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6434#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6435#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6436#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6437#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6438#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6439#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6440#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6441#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6442#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6443#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6444#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6445#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6446#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6447#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6448#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6449#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6450#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6451#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6452#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6453#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6454#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6455#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6456#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6457#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6458#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6459#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6460#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6461#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6462#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6463#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6464#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6465#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6466#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6467#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6468#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6469#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6470#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6471#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6472#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6473#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6474#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6475#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6476#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6477#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6478#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6479#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6480#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6481#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6482#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6483#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6484#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6485#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6486#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6487#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6488#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6489#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6490#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6491#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6492#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6493#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6494#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6495#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6496#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6497#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6498#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6499#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6500#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6501#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6502#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6503#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6504#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6505#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6506#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6507#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6508#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6509#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6510#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6511#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6512#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6513#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6514#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6515#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6516#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6517#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6518#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6519#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6520#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6521#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6522#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6523#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6524#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6525#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6526#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6527#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6528#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6529#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6530#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6531#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6532#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6533#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6534#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6535#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6536#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6537#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6538#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6539#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6540#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6541#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6542#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6543#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6544#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6545#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6546#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6547#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6548#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6549#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6550#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6551#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6552#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6553#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6554#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6555#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6556#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6557#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6558#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6559#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6560#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6561#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6562#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6563#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6564#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6565#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6566#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6567#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6568#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6569#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6570#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6571#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6572#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6573#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6574#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6575#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6576#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6577#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6578#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6579#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6580#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6581#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6582#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6583#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6584#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6585#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6586#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6587#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6588#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6589#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6590#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6591#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6592#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6593#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6594#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6595#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6596#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6597#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6598#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6599#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6600#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6601#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6602#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6603#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6604#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6605#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6606#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6607#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6608#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6609#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6610#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6611#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6612#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6613#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6614#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6615#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6616#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6617#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6618#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6619#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6620#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6621#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6622#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6623#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6624#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6625#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6626#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6627#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6628#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6629#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6630#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6631#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6632#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6633#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6634#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6635#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6636#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6637#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6638#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6639#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6640#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6641#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6642#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6643#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6644#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6645#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6646#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6647#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6648#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6649#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6650#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6651#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6652#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6653#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6654#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6655#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6656#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6657#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6658#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6659#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6660#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6661#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6662#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6663#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6664#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6665#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6666#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6667#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6668#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6669#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6670#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6671#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6672#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6673#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6674#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6675#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6676#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6677#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6678#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6679#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6680#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6681#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6682#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6683#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6684#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6685#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6686#.XCepzVxKiUl
# ...
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6806#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6807#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6808#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6809#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6810#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6811#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6812#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6813#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6814#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6815#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6816#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6817#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6818#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6819#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6820#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6821#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6822#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6823#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6824#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6825#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6826#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6827#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6828#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6829#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6830#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6831#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6832#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6833#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6834#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6835#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6836#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6837#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6838#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6839#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6840#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6841#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6842#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6843#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6844#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6845#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6846#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6847#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6848#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6849#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6850#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6851#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6852#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6853#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6854#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6855#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6856#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6857#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6858#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6859#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6860#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6861#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6862#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6863#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6864#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6865#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6866#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6867#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6868#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6869#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6870#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6871#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6872#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6873#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6874#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6875#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6876#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6877#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6878#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6879#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6880#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6881#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6882#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6883#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6884#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6885#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6886#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6887#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6888#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6889#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6890#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6891#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6892#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6893#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6894#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6895#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6896#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6897#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6898#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6899#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6900#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6901#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6902#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6903#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6904#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6905#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6906#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6907#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6908#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6909#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6910#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6911#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6912#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6913#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6914#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6915#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6916#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6917#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6918#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6919#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6920#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6921#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6922#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6923#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6924#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6925#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6926#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6927#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6928#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6929#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6930#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6931#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6932#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6933#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6934#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6935#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6936#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6937#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6938#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6939#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6940#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6941#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6942#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6943#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6944#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6945#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6946#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6947#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6948#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6949#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6950#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6951#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6952#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6953#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6954#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6955#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6956#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6957#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6958#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6959#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6960#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6961#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6962#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6963#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6964#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6965#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6966#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6967#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6968#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6969#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6970#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6971#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6972#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6973#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6974#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6975#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6976#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6977#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6978#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6979#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6980#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6981#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6982#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6983#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6984#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6985#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6986#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6987#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6988#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6989#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6990#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6991#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6992#.XCepzVxKiUl
# <Response [200]>
# An exception occurred
# https://www.diecastmodelaircraft.com/db/model/6993#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6994#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6995#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6996#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6997#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6998#.XCepzVxKiUl
# <Response [200]>
# https://www.diecastmodelaircraft.com/db/model/6999#.XCepzVxKiUl
# <Response [200]>

# %%
#migrate from local to global
import pandas as pd
cursor = colmodels.find()
# Expand the cursor and construct the DataFrame
df =  pd.DataFrame(list(cursor))
df.head()
# Out:
#                         _id Manufacturer                  Make/Model  \
# 0  615c5df1002ec44d92693b9c       Schuco  Airbus Industries A320-211
# 1  615c5df2002ec44d92693b9d       Schuco            Boeing B 727-230
# 2  615c5df2002ec44d92693b9e       Schuco           Boeing B 737-230A
# 3  615c5df2002ec44d92693b9f       Schuco          Boeing B 737-290CA
# 4  615c5df3002ec44d92693ba0       Schuco            Boeing B 747-143
#
#            Airline  Scale   Part # DiMA ID # Registration         Engines  \
# 0        Lufthansa  1:400  3557352      6000       D-AIPB     2 CFM56-5A1
# 1        Lufthansa  1:400  3557354      6001       D-ABCI       3 JT8D-15
# 2        Lufthansa  1:400  3557351      6002       D-ABFX  2 JT8D-15(HK3)
# 3  Alaska Airlines  1:400  3557372      6003       N730AS  2 JT8D-17(HK3)
# 4         Alitalia  1:400  3557358      6004       I-DEMA       4 JT9D-7A
#
#                     Country  ...                                    Notes  \
# 0                   Germany  ...      "1990s" Colors. Named "Heidelberg".
# 1                   Germany  ...       "1980s" Colors. Named "Karlsruhe".
# 2                   Germany  ...        "1980s" Colors. Named "T�bingen".
# 3  United States of America  ...                          "1990s" Colors.
# 4                     Italy  ...  "1980s" Colors. Named "Neil Armstrong".
#
#   2003 - 2003 2000   No "1998s" Colors Quick Stats Retailers & Trades  \
# 0         NaN  NaN  NaN            NaN         NaN                NaN
# 1         NaN  NaN  NaN            NaN         NaN                NaN
# 2         NaN  NaN  NaN            NaN         NaN                NaN
# 3         NaN  NaN  NaN            NaN         NaN                NaN
# 4         NaN  NaN  NaN            NaN         NaN                NaN
#
#   Got it! - Use these to add this model to your online collection!  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   This model and others on \n\nCollapse Retailer Availability\n\nCollapse
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
# [5 rows x 25 columns]

# %%
master_lst
# Out:
# [{'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 737-536',
#   'Airline': 'British Airways',
#   'Scale': '1:500',
#   'Part #': '0',
#   'DiMA ID #': '1',
#   'Registration': 'NA',
#   'Engines': '2 CFM56-3C1',
#   'Country': 'Great Britain',
#   'Continent': 'Europe',
#   'Production': '1993 - 1993',
#   'Units Made': '20',
#   'Rolling Gears': 'No',
#   'Includes Stand': 'No',
#   'Notes': '"Landor" Colors.'},
#  {'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 747-436',
#   'Airline': 'British Airways',
#   'Scale': '1:500',
#   'Part #': '500708',
#   'DiMA ID #': '2',
#   'Registration': 'NA',
#   'Engines': '4 RB211-524H2',
#   'Country': 'Great Britain',
#   'Continent': 'Europe',
#   'Production': '1996 - 1997',
#   'Units Made': 'Unlimited',
#   'Rolling Gears': 'No',
#   'Includes Stand': 'No',
#   'Notes': 'Second Version, "Landor" Colors. With Updated Window Line.'},
#  {'Manufacturer': 'Herpa',
#   'Make/Model': 'Boeing B 747-436',
#   'Airline': 'British Airways',
#   'Scale': '1:500',
#   'Part #': '500708',
#   'DiMA ID #': '3',
#   'Registration': 'NA',
#   'Engines': '4 RB211-524H2',
#   'Country': 'Great Britain',
#   'Continent': 'Europe',
#   'Production': '1997 - 1998',
#   'Units Made': 'Unlimited',
#   'Rolling Gears': 'No',
#   'Includes Stand': 'No',
#   'Notes': 'Third Version, "Landor" Colors. With Updated Engines.'}]

# %%
results = soup.find_all('td')#,class_="align=")
data={}
lst=[]
master_lst=[]
for result in results:
    #print(result.text)
    #result=result.strip(":")
    lst.append(result.text.strip())
    # Error handling
    #try:
        # Identify and return title of listing
        #title = result.find('span').text
       # print(title)

lst=list(filter(None,lst))
lst
print(len(lst))
for i in range (0,30-1,2):
    #print(i)
    data[lst[i].strip(":")]=lst[i+1]
    

data
#master_lst.append[data]
#data={}
