# %%
# Dependencies
import requests
import json
import html
from bs4 import BeautifulSoup
#from config import api_key
import time
import pprint as pprint
url = "https://www.diecastmodelaircraft.com/db/model/"
api_key="#.XCepzVxKiUl"

# %%
for i in range(1,2):
    strng=url+str(i)+api_key
    print(strng)
    response=requests.get(strng)
    soup = BeautifulSoup(response.text, 'html')
    #print(requests.get(strng))
    #response_j=(response.json())
    print(soup)
# Out:
# https://www.diecastmodelaircraft.com/db/model/1#.XCepzVxKiUl
# <html><head><link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <!DOCTYPE html>
#
# <base href="https://database.diecastmodelaircraft.com/"/>
# <link href="favicon.ico" rel="Shortcut Icon" type="image/x-icon"/>
# <link href="https://www.diecastmodelaircraft.com/core/clientscript/vbulletin_css/style00014l/1609632095-main-cssnormalization.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.diecastmodelaircraft.com/core/clientscript/vbulletin_css/style00014l/1609632095-main.css" rel="stylesheet" type="text/css"/>
# <meta content="119964314835334" property="fb:app_id"/>
# <meta content="Diecast Model Aircraft (DiMA)" property="og:site_name"/>
# <meta content="" property="og:description"/>
# <meta content="https://www.diecastmodelaircraft.com" property="og:url"/>
# <meta content="https://www.diecastmodelaircraft.com/images/misc/vbulletin5_logo.png" property="og:image"/>
# <meta content="website" property="og:type"/>
# <link href="xmlsitemap.php" rel="sitemap" type="application/xml"/>
# <link href="https://database.diecastmodelaircraft.com" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="vBulletin 5.6.4" name="generator"/>
# <link href="https://www.diecastmodelaircraft.com/core/clientscript/vbulletin_css/style00014l/1609632095-css_login.css" rel="stylesheet" type="text/css"/>
# </head><body class="l-desktop page vb-page view-mode logged-out" data-styleid="14" data-usergroupid="1" id="vb-page-body" itemscope="">
# <div class="b-top-menu__background b-top-menu__background--sitebuilder js-top-menu-sitebuilder h-hide-on-small h-hide">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list js-shrink-event-parent">
# </ul>
# </div>
# </div>
# <nav class="b-top-menu__background js-top-menu-user">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--user js-top-menu-user--list js-shrink-event-parent">
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content b-comp-menu-dropdown__content--right">
# </ul>
# </ul></div>
# </nav>
# <div class="noselect h-clearfix h-hide-on-small" id="sitebuilder-wrapper">
# </div>
# <div class="main-navbar-bottom-line"></div>
# <div id="outer-wrapper">
# <div id="wrapper">
# <div class="header-edit-box axdnum_1 h-clearfix" id="header-axd" style="position: absolute !important; margin-top: 25px;margin-left: 150px;">
# <div class="axd-container axd-container_header">
# <div class="admin-only">
# </div>
# <div class="axd axd_header">
# <div class="ad_header_inner">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- DIMA Responsive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2116603283" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# </div>
# <div class="axd-container axd-container_header2">
# <div class="admin-only">
# </div>
# <div class="axd axd_header2">
# </div>
# </div>
# </div>
# <header class="b-top-background__header-mainnav-subnav">
# <div class="b-top-background__header-mainnav">
# <div class="noselect" id="header">
# <div class="header-cell">
# <div class="site-logo header-edit-box">
# <a href="https://www.diecastmodelaircraft.com/"><img alt="Logo" data-orig-src="images/misc/vbulletin5_logo.png" src="https://www.diecastmodelaircraft.com/images/misc/vbulletin5_logo.png" title="Powered by vBulletin"/></a>
# </div>
# </div>
# <div class="toolbar">
# <ul class="h-right">
# <li class="search-container">
# <form action="https://www.diecastmodelaircraft.com/search" class="h-left" id="searchForm" method="GET">
# <div class="h-left">
# <div class="search-box h-clearfix">
# <div class="search-term-container">
# <input autocomplete="off" class="search-term b-form-input__input b-form-input__input--shadow" id="q" name="q" placeholder="Search" type="text"/>
# <div class="search-menu-container h-clearfix">
# <div class="vertical-divider-left"></div>
# <div class="b-comp-menu-dropdown js-comp-menu-dropdown b-comp-menu-dropdown--open-on-hover b-comp-menu-dropdown--header-search">
# <div class="b-comp-menu-dropdown__trigger js-comp-menu-dropdown__trigger b-comp-menu-dropdown__trigger--arrow js-button" tabindex="0"></div>
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content">
# <li class="b-comp-menu-dropdown__content-item b-comp-menu-dropdown__content-item--first b-comp-menu-dropdown__content-item--no-hover js-comp-menu-dropdown__content-maintain-menu">
# <div class="searchPopupBody">
# <label><input class="searchFields_title_only" name="searchFields[title_only]" type="checkbox" value="1"/>Search in titles only</label>
# <div class="b-button-group h-margin-top-xs">
# <button class="b-button b-button--primary" id="btnSearch-popup" type="submit">Search</button>
# </div>
# </div>
# <input name="searchJSON" type="hidden" value=""/>
# </li>
# <li class="b-comp-menu-dropdown__content-item js-comp-menu-dropdown__content-maintain-menu">
# <a class="adv-search-btn" href="#" id="btnAdvSearch">Advanced Search</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <button class="search-btn" id="btnSearch" title="Search" type="submit"><span class="b-icon b-icon__search"></span></button>
# </div>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </div>
# <nav class="h-clearfix noselect" id="channel-tabbar">
# <ul class="channel-tabbar-list h-left b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-small b-comp-menu-dropdown--inactive js-comp-menu-dropdown__content--main-menu h-hide-on-small js-shrink-event-parent">
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_test" href="https://www.diecastmodelaircraft.com/">Home</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_discuss" href="https://www.diecastmodelaircraft.com/discuss">Discuss</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="current section-item js-shrink-event-child">
# <a class="h-left navbar_database" href="https://database.diecastmodelaircraft.com">Database</a>
# <span class="channel-tabbar-divider"></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_collect" href="collect">Collect</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_trade" href="db/tradesearch">Trades</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_want" href="db/wantsearch">Wanted</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_airport" href="https://www.diecastmodelaircraft.com/airports">Airport</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_members" href="memberlist">Members</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_shop" href="https://www.diecastmodelaircraft.com/shop">Shop</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_register" href="https://www.diecastmodelaircraft.com/register">Register</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class="section-item js-shrink-event-child">
# <a class="h-left navbar_contact" href="https://www.diecastmodelaircraft.com/contact-us">Contact</a>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# </ul>
# </nav>
# </div>
# <nav class="h-clearfix h-hide-on-small h-block js-channel-subtabbar" id="channel-subtabbar">
# <ul class="h-left channel-subtabbar-list js-channel-subtabbar-list js-shrink-event-parent">
# <li class="js-shrink-event-child"><a href="/newest">Newest Models</a></li>
# <li class="js-shrink-event-child"><a href="/toplist">Top Models List</a></li>
# <li class="js-shrink-event-child"><a href="/1:200">1:200</a></li>
# <li class="js-shrink-event-child"><a href="/1:400">1:400</a></li>
# <li class="js-shrink-event-child"><a href="/1:500">1:500</a></li>
# <li class="js-shrink-event-child"><a href="/1:600">1:600</a></li>
# <li class="js-shrink-event-child"><a href="/AeroClassics">AeroClassics</a></li>
# <li class="js-shrink-event-child"><a href="/dragon">Dragon Wings</a></li>
# <li class="js-shrink-event-child"><a href="/GeminiJets">GeminiJets</a></li>
# <li class="js-shrink-event-child"><a href="/Herpa">Herpa</a></li>
# <li class="js-shrink-event-child"><a href="/Hogan">Hogan</a></li>
# <li class="js-shrink-event-child"><a href="/Inflight">Inflight</a></li>
# <li class="js-shrink-event-child"><a href="/JCWings">JCWings</a></li>
# <li class="js-shrink-event-child"><a href="/Phoenix">Phoenix</a></li>
# </ul>
# </nav>
# </header>
# <main id="content">
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <title>Herpa 1:500 British Airways B 737-536 0 Diecast Airplane | DiecastModelAircraft.com</title>
# <meta content="Details and photos for Herpa's 1:500 scale diecast aircraft model of a British Airways B 737-536. Herpa part# 0" name="description"/>
# <meta content="Herpa,1:500,British Airways,B 737-536,0,diecast,die cast,model,aircraft,database,airplane,scale" name="keywords"/>
# <link href="/styles/dima.css" rel="stylesheet" type="text/css"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.1" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.2" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <img src="https://www.wafflecollectibles.com/custom/image.php?ref=1.3" style="opacity: 0;position: absolute;top:0; left:0; z-index:-300;"/>
# <script language="JavaScript">
# <!--
# function autoResize(id){
#     var newheight;
#     var newwidth;
#
#     if(document.getElementById){
#         newheight=document.getElementById(id).contentWindow.document .body.scrollHeight;
#         newwidth=document.getElementById(id).contentWindow.document .body.scrollWidth;
#     }
#     if(newheight<50)
#        { document.getElementById(id).height= "25px";
# 	document.getElementById(id).scrolling= "no"; }
#     if(newheight>300)
# 	{ document.getElementById(id).height= "300px";	}
# 	else { 	document.getElementById(id).height= (newheight) + "px"; }
# }
# //-->
# </script>
# <div class="tabs settingsTabs ui-tabs underline-tabs-container ui-widget ui-corner-all" style="padding-bottom: 5px !important; border-bottom: 1px solid #AAAAAA;">
# <a href="/search" id="userSettingsProfile" style="padding: 5px;background: #EEEEEE;text-decoration: ;border-radius: 5px;border: #000000;border: solid #CCCCCC 1px;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="vertical-align:3px;">Quick Search</span></a>
# <a href="/advanced?3574" id="userSettingsAccount" style="padding: 5px;background: #EEEEEE;text-decoration: ;border-radius: 5px;border: #000000;border: solid #CCCCCC 1px;">
# <img src="/images/icons/search.png"/>
# <span class="label" style="vertical-align:3px;">Advanced Search</span></a>
# <a href="#" id="userSettingsAccount" style="padding: 5px;background: #EEEEEE;text-decoration: ;border-radius: 5px;border: #000000;border: solid #CCCCCC 1px;">
# <img src="/images/icons/info.png"/>
# <span class="label" style="vertical-align:3px;"><b>Model Details</b></span></a>
# </div>
# <div class="canvas-layout-container"><!-- END: header -->
# <div class="canvas-layout row-fluid interconnected-widgets private-message-widget-layout" data-layout-id="4" id="canvas-layout-30-70">
# <!-- section 0, 1 -->
# <div class="canvas-layout-row has-columns" style="display: inline;">
# <div class="canvas-widget-list section-0 has-adjacent-right-col span4" style="width: 175px !important;">
# <!-- BEGIN: widget_privatemessage_navigation -->
# <div class="canvas-widget default-widget private-message-widget widget-no-header widget-no-border left-nav" data-widget-id="184" data-widget-instance-id="" style="border-right: 1px solid #C9CED2; border-left: 1px solid #C9CED2; border-bottom: 1px solid #C9CED2; margin-left: -1px;">
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message Navigation<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# <span class="edit-button module-button-item" title="Edit module"><span>Edit</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="widget-content">
# <div class="sb-dialog stretch" id="pmInfoDialogNav">
# <div class="dialog-content stretch" id="pmInfoContentNav">
# </div>
# <div class="action-buttons">
# <button class="button primary" id="pmInfoCloseNav" type="button">Close</button>
# </div>
# </div>
# <div class="clearfix" id="privateMessageNavContainer">
# <div class="nav-pane" style="background: #F4f4f4; padding-top:10px;">
# <center>
# <img class="imgbox" src="http://database.diecastmodelaircraft.com/images/scales/1500.png" style="vertical-align:middle !important;"/><br/>Scale
#
# <p><img alt="Herpa" class="imgbox" nopin="nopin" src="https:/images/manuf/herpawings.gif"/><br/>Herpa
# </p><p><img alt="British Airways" class="imgbox" src="/logo.3574.gif"/><br/>British Airways
#
# </p><p><img alt="Great Britain" border="1" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/images/flags/GB.gif"/><br/><font face="Arial" size="1" style="font-size: 10pt">Great Britain</font>
# </p><p><img align="absmiddle" alt="Europe" class="imgbox" nopin="nopin" src="https://www.wafflecollectibles.com/db/continents/europe.png"/><br/><font face="Arial" size="1" style="font-size: 10pt">Europe
#
# 				</font></p></center>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <!--Inbox-->
# <div class="folder-item special-folder inbox">
# <a class="selected" href="/collect">
# <span class="label ellipsis" style="margin-left:25px;">Your Collection</span>
# </a>
# </div>
# <iframe height="100" marginheight="4" marginwidth="4" scrolling="no" src="/iframe/modelinfo-collect.php?id=1" style="border: 1;" width="160"></iframe>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:35px;">Model Value</span>
# </a>
# </div>
# <iframe height="50" marginheight="4" marginwidth="4" scrolling="no" src="/iframe/value.php?id=1" style="border: 1;" width="160"></iframe>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:21px;">Model Popularity</span>
# </a>
# </div>
# <script src="/RGraph/libraries/RGraph.common.core.js"></script>
# <script src="/RGraph/libraries/RGraph.common.dynamic.js"></script>
# <script src="/RGraph/libraries/RGraph.meter.js"></script>
# <!--[if lt IE 9]><script src="/RGraph/excanvas/excanvas.js"></script><![endif]-->
# <canvas height="100" id="cvs" style="border: 0px solid #ccc" width="172">[No canvas support]</canvas>
# <script>
#         window.onload = function ()
#         {
#             var meter = new RGraph.Meter('cvs', 0,100,0);
#             meter.Set('angles.start', PI - 0.0);
#             meter.Set('angles.end', TWOPI + 0.0);
#             meter.Set('linewidth.segments', 10);
#             meter.Set('text.size', 9);
#             meter.Set('strokestyle', 'white');
#             meter.Set('segment.radius.start', 0);
#             meter.Set('chart.border', 0);
#             meter.Set('tickmarks.small.num', 0);
#             meter.Set('tickmarks.big.num', 0);
# 	    meter.Set('chart.needle.radius', 50);
#             meter.Set('chart.needle.linewidth', 1);
#     	    meter.Set('chart.red.color', '#D20707');
#     	    meter.Set('chart.red.start', 10);
#     	    meter.Set('chart.red.end', 40);
#     	    meter.Set('chart.yellow.color', '#FFD104');
#     	    meter.Set('chart.yellow.start', 40)
#     	    meter.Set('chart.yellow.end', 75);
#     	    meter.Set('chart.green.color', '#3B7F3B');
#     	    meter.Set('chart.green.start', 75);
# 	meter.Set('chart.shadow',1);
# 	meter.Set('chart.shadow.color','#e5e5e5');
# 	meter.Set('chart.shadow.blur',15);
# 	meter.Set('chart.shadow.offsetx',0);
# 	meter.Set('chart.shadow.offsety',10);
#             meter.Draw();
#
#
#         }
#     </script>
# <br/>
# <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; margin-left:10px !important; font-size:13px;">
# Popularity Score:
# </span></a>
# <span class="databox" style="font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/collectors/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Collected:
# </span></a><span class="databox">
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/buyers/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Wanted:
# </span></a><span class="databox">
# 0</span></div>
# <div class="folder-item special-folder notifications"><a href="/trades/1"><span class="icon"></span><span class="label ellipsis" style="margin-left:10px !important;">
# Trading:
# </span></a><span class="databox">
# 0</span></div>
# </div>
# <hr class="divider-solid"/>
# <div class="folder-list">
# <!--Inbox-->
# <div class="folder-item special-folder inbox">
# <a href="/model/1">
# <span class="label ellipsis" style="margin-left:45px;">Model Size</span>
# </a>
# </div>
# <!--Messages-->
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Length: 6.20cm / 2.42"</font>
# </span>
# </a>
# </div>
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Wingspan: 5.78cm / 2.25"</font>
# </span>
# </a>
# </div>
# <div class="folder-item special-folder messages">
# <a href="javascript:void(0)">
# <span class="label ellipsis" style="width: 155px !important; margin-left: 5px !important; overflow: visible !important;">
# <font size="2">Height: 2.23cm / 0.87"</font></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- END: widget_privatemessage_navigation -->
# </div><div class="canvas-widget-list section-1 has-adjacent-left-col span8" style="padding-left: 176px !important;">
# <!-- BEGIN: widget_privatemessage_toolbar -->
# <div class="canvas-widget default-widget private-message-widget widget-no-header widget-no-border private-message-toolbar empty" data-widget-id="186" data-widget-instance-id="" style="padding-top: 7px; background: #F4f4f4 !important; padding-bottom: 8px; margin-bottom:0px; border-bottom: 1px solid #C9CED2;">
# <center><span style="font-size: 16px !important;">Herpa British Airways B 737-536 1:500</span>
# </center></div>
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message Toolbar<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="canvas-widget default-widget private-message-widget conversation-content-widget widget-no-header widget-no-border private-message-display" data-widget-id="182" data-widget-instance-id="">
# <div class="widget-header admin-only clearfix">
# <div class="module-title left">Message<span class="admin-only"> Module</span></div>
# <div class="module-buttons">
# <span class="admin-only">
# <span class="move-icon module-button-item" title="Move module"><span>Move</span></span>
# </span>
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse"><span>Collapse</span></span>
# </div>
# </div>
# <div class="widget-content" style="width: 80% !important; border-right: solid 1px #C8CCCE">
# <div class="sb-dialog" id="pmInfoDialog">
# <div class="dialog-content" id="pmInfoContent"></div>
# </div>
# <div class="clearfix" id="privateMessageContainer">
# <div class="main-pane clearfix">
# <!-- BEGIN: privatemessage_foldersummary --><div class="main-pane-container">
# <center><br/>
# <table border="0" cellpadding="0" cellspacing="0" style="border-color: #FFFFFF; border: solid 0px;  border-collapse:collapse;" width="95%">
# <tr>
# <td align="right" bgcolor="#F4F4F4"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Manufacturer:</font></td>
# <td><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt"><span><a href="/manufacturer/Herpa">Herpa</a></span></font></td>
# <td align="right" bgcolor="#F4F4F4"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Make/Model:</font></td>
# <td><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt"><span>Boeing B 737-536</span></font></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Airline:</font></b>
# </td><td>British Airways</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Scale:</font></b></td>
# <td>1:500</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Part #:</font></b></td>
# <td><span class="purplemed"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt">0</font></span></td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">DiMA ID #:</font></b></td>
# <td><span class="purplemed"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt">1</font></span></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Registration:</font></td>
# <td><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt"><span>NA</span></font></td>
# <td align="right" bgcolor="#F4F4F4"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Engines:</font></td>
# <td><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt"><span>2 CFM56-3C1</span></font></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">
#                                                 Country:</font></td>
# <td><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt">
# <span>Great Britain</span></font></td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Continent:</font></b></td>
# <td><span class="purplemed"><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt">Europe</font></span></td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Production:</font></b></td>
# <td>1993 - 1993</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Units Made:</font></b></td>
# <td>20</td>
# </tr>
# <tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Rolling Gears:</font></b></td>
# <td>No</td>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Includes Stand:</font></b></td>
# <td>No</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr><tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Notes:</font></b></td>
# <td colspan="4">"Landor" Colors.</td>
# </tr>
# <tr><td style="height:2px !important; padding: .1em;"></td></tr><tr>
# <td align="right" bgcolor="#F4F4F4"><b><font arial="" face="" open="" sans="" size="1" style="font-size: 10pt; font-weight:700">Quick Stats:</font></b></td>
# <td colspan="4">
# <div class="folder-item special-folder notifications"><a href="javascript:void(0)"><span class="icon"></span><span class="label ellipsis" style="color: black; font-size:13px;">
# Popularity Score:</span></a>
# <span class="databox" style="position: relative;left: 2px;width: 15px; font-size: 13px; color: black; background: #F4F4F4 D44B46 !important;">
#
# 0</span>
# <span style="padding-left: 10px;">
# Collectors <a href="/collectors/1">(0)</a>
# Buyers <a href="/buyers/1">(0)</a>
# Traders <a href="/trades-available/1">(0)</a>
# </span>
# </div>
# </td></tr>
# </table>
# <h2 class="main-pane-header" style="width: 713px;"><center><span font-size:14px="" open="" sans="" style="font-family: "><b>Model Photos</b></span></center></h2>
# <iframe frameborder="0" height="515" scrolling="no" src="/iframe/galleria.php?mid=1" width="100%"></iframe>
# <a class="variousedit" data-fancybox-type="iframe" href="https://www.wafflecollectibles.com/custom/upload.php?id=1&amp;bbuserid=&amp;bbusername=" title="Upload a Photo of this model"><img src="/images/icons/upload.png"/>
# Upload a photo of this model!</a>
# </center></div>
# <!-- END: privatemessage_foldersummary -->
# </div>
# </div>
# </div>
# <!-- Right space begin -->
# <div class="widget-content" style="width: 275px !important; border: solid 0px; display:inline; position: absolute;">
# <center>
# <table style="border: dashed 1px #b4b4b4; margin-top:0px;">
# <tr>
# <td align="center" style="cursor: pointer">
# <img src="https://www.ebayadservices.com/marketingtracking/v1/impression?mpt=[CACHEBUSTER]&amp;mkcid=1&amp;mkrid=711-53200-19255-0&amp;mkevt=2&amp;siteid=0&amp;campid=5337235573&amp;ad_type=0&amp;toolid=10001" style="text-decoration:none;border:0;padding:0;margin:0;"/>
# <a href="
# https://www.ebay.com/sch/i.html?_from=R40&amp;_trksid=p2380057.m570.l1313&amp;_nkw=
# %28Herpa,%20British+Airways,%20737%29+%28%29
# &amp;_sacat=0&amp;mkrid=711-53200-19255-0&amp;siteid=0&amp;mkcid=1&amp;campid=
# 5337235573
# &amp;toolid=10001&amp;customid=&amp;mkevt=1
# " target="_blank">
# <img src="/ebaystatus/%28Herpa,%20British+Airways,%20737%29+%28%29/1"/></a>
# </td></tr>
# <tr><td align="center">Retailers &amp; Trades</td></tr>
# <tr><td align="center">
# <a href="/availability/1"><img src="/stock/1" style="margin-top:5px;"/></a>
# 			<a href="/trades/1"><img src="/trades/1" style="margin-top:5px;"/></a>
# </td></tr>
# </table>
# <table><tr><td>
# <span style="font-size:12px !important;">You can use these links throughout to help manage your collection and want list:
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/aircraft.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Got it!</b> - Use these to add this model to your online collection!<br/>
# </span></td></tr>
# <tr><td>
# <img src="/images/icons/heart.png" style="padding-left: 10px; padding-right:6px;"/>
# <span style="font-size:11px !important;"><b>Want it!</b> - Add the model to your Want list, and we will email you when it is in stock!	<br/>
# <tr><td>
# <p>
# </p><center>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Right 200x200 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2768462515" style="display:inline-block;width:200px;height:200px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </center>
# </td></tr>
# </span></td></tr></table>
# <!-- BEGIN: footer --></center></div>
# <br/>
# <table width="100%%"><tr><td align="left" width="550">
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	This model and others on <img nopin="nopin" src="/images/ebay_logo.png" valign="absmiddle"/>
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="350" id="iframe1" marginheight="0" src="/iframe/rss.php?search=%28Herpa,%20British Airways,%20B 737-536%29%20%280%29&amp;search2=%28Herpa,%20British Airways%29" width="100%"></iframe>
# </div></div>
# </td><td>
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Value Graphs
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <center><table align="center" style="margin-bottom: 0px !important;"><tr><td>
# <iframe height="350" scrolling="no" src="/iframe/avggraph.php?mid=1" width="470"></iframe>
# </td></tr></table>
# </center></div>
# </div>
# </td></tr></table>
# <table width="100%%"><tr><td align="left" width="550">
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# 	Retailer Availability
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="220" id="iframe1" marginheight="0" src="/iframe/availability-list-narrow.php?mid=1" width="100%"></iframe>
# </div></div>
# </td><td>
# <div class="canvas-widget birthday-widget" data-widget-id="293" data-widget-instance-id="168">
# <div class="widget-header clearfix"><div class="module-title left"><span class="main-title hide-on-editmode" style="font-size: 15px !important;">
# Collectors of this Model
# </span></div><div class="module-buttons"><span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Collapse">
# <span class="vb-icon vb-icon-toggle">Collapse</span></span></div></div>
# <div class="widget-content">
# <iframe height="220" src="/iframe/collectors.php?mid=1" width="100%"></iframe>
# </div>
# </div>
# </td></tr></table>
# <p></p><center>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script> <!-- DIMA Responsive --> <ins class="adsbygoogle" data-ad-client="ca-pub-3214934421390310" data-ad-slot="2116603283" style="display:inline-block;width:728px;height:90px"></ins> <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <footer id="footer">
# <nav class="h-clearfix js-shrink-event-parent" id="footer-tabbar">
# <ul class="h-left js-footer-chooser-list h-margin-left-xxl js-shrink-event-child">
# </ul>
# <ul class="nav-list h-right js-footer-nav-list h-margin-right-xxl b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-xsmall b-comp-menu-dropdown--inactive js-shrink-event-child" data-dropdown-menu-classes="h-margin-vert-l b-comp-menu-dropdown--direction-up" data-dropdown-trigger-classes="b-comp-menu-dropdown__trigger--arrow" data-dropdown-trigger-phrase="go_to_ellipsis">
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/help">Help</a>
# </li>
# <li class="current">
# <a href="https://www.diecastmodelaircraft.com/">Home</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/discuss">Discuss</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/db">Database</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/collect">Collect</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/want">Wanted</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/shop">Shop</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/memberlist">Member List</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/blogs">Blogs</a>
# </li>
# <li class="">
# <a href="https://www.diecastmodelaircraft.com/social-groups">Groups</a>
# </li>
# <li><a class="js-footer-go-to-top" href="#">Go to top</a></li>
# </ul>
# </nav>
# </footer>
# </center></div>
# <div id="footer-copyright">
# <div id="footer-user-copyright">© 2021 DiMA DiecastModelAircraft.com. The website, content,  design and  pictures and are intended for public commercial and non-commercial use of Waffle Collectibles LLC, and may be redistributed, freely printed, or electronically reproduced in its complete and unaltered form provided distribution is for the use of Waffle Collectibles LLC and it's affiliated websites only. Partial and other distribution means require the permission of DiMA &amp; Waffle Collectibles LLC. All rights reserved. Airline Logos are used under license from AirlineLogos.net</div>
# <div id="footer-vb-copyright">Powered by <a href="https://www.vbulletin.com" id="vbulletinlink">vBulletin®</a> Version 5.6.4 <br/>Copyright © 2021 MH Sub I, LLC dba vBulletin. All rights reserved. </div>
# <div id="footer-current-datetime">All times are GMT-5. This page was generated at 10:21 AM.</div>
# </div>
# </div>
# <div class="js-loading-indicator b-ajax-loading-indicator h-hide" id="loading-indicator">
# <span>Working...</span>
# </div>
# <div class="js-flash-message b-ajax-loading-indicator b-ajax-loading-indicator--medium h-hide">
# <span class="js-flash-message-content"></span>
# </div>
# <div class="sb-dialog" id="confirm-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnConfirmDialogYes" type="button">Yes</button>
# <button class="b-button b-button--secondary js-button" id="btnConfirmDialogNo" type="button">No</button>
# </div>
# </div>
# <div class="sb-dialog" id="alert-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnAlertDialogOK" type="button">OK</button>
# </div>
# </div>
# <div class="sb-dialog" id="prompt-dialog">
# <div class="dialog-content table h-clearfix">
# <div class="message td"></div>
# <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>
# </div>
# <div class="js-prompt-error h-hide"></div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnPromptDialogOK" type="button">OK</button>
# <button class="b-button b-button--secondary js-button" id="btnPromptDialogCancel" type="button">Cancel</button>
# </div>
# </div>
# <div class="sb-dialog slideshow" id="slideshow-dialog">
# <div class="b-icon b-icon__x-square--gray close-btn">X</div>
# <div class="slideshow-wrapper"></div>
# <div class="caption"></div>
# <div class="thumbnails-wrapper">
# <div class="thumbnails"></div>
# </div>
# </div>
# <div class="unsubscribe-overlay-container"></div>
# <div data-facebook-language="en_US" id="fb-root"></div>
# <script type="text/javascript">
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-8194867-14', 'auto');
#   ga('send', 'pageview');
# </script>
# </div></div></main></div></div></body></html>

# %%
results = soup.find_all('title')
for result in results:
   
    print(result.text)
# Out:
# Herpa 1:500 British Airways B 737-536 0 Diecast Airplane | DiecastModelAircraft.com

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
# Out:
# A snippet from the article: Congressional Republicans won’t pass even basic, sensible gun-safety measures, so Mr. Obama is doing what he can through executive actions.
# A snippet from the article: The hourlong event will be televised on CNN, and will come days after President Obama meets with the attorney general to discuss gun control.
# A snippet from the article: President Obama will meet with Attorney General Loretta E. Lynch on Monday to discuss what he can do to curb gun violence, sidestepping an entrenched Congress.
# A snippet from the article: After his friend was shot to death in 2013, Chris Wilmore began actively recruiting people to settle their disputes with gloves, not guns.
# A snippet from the article: Readers respond to an Op-Ed essay by the president calling for the country to join together to fight the gun crisis.
# A snippet from the article: Jim Fox, a leader of a Long Island league and of the Amateur Athletic Union in the New York area, is helping to have patches displayed on thousands of young people&#8217;s uniforms.
# A snippet from the article: The exhausting dance between black death and black scribe is journalism and catharsis.
# A snippet from the article: The Sanders campaign has mailed Iowa voters literature that outlines his record on gun control, suggesting how much he is on the defensive on the issue with the caucuses only a week away.
# A snippet from the article: Shortcomings in federal and state law allow many domestic abusers to have access to firearms.
# A snippet from the article: Hillary Clinton, appearing with the president of the Brady Campaign to Prevent Gun Violence, attacked Bernie Sanders on his 2005 vote to shield gunmakers from lawsuits.

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    pprint.pprint(articles)
    # Add a one second interval between queries to stay within API query limits
    time.sleep(3)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
# Out:
# {'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': '568b248038f0d85e74bd0b7b',
#                         'blog': {},
#                         'byline': {'organization': 'THE EDITORIAL BOARD',
#                                    'original': 'By THE EDITORIAL BOARD',
#                                    'person': []},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Editorial',
#                                      'kicker': 'Editorial',
#                                      'main': 'The President Acts on Gun '
#                                              'Violence',
#                                      'name': None,
#                                      'print_headline': 'The President Acts on '
#                                                        'Gun Violence',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Editorials'},
#                                      {'major': 'N',
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'United States Politics and '
#                                                'Government'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Gun Control'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 726,
#                                         'legacy': {'xlarge': 'images/2016/01/05/opinion/05tue2/05tue2-articleLarge.jpg',
#                                                    'xlargeheight': 726,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/05/opinion/05tue2/05tue2-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/05/opinion/05tue2/05tue2-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/05/opinion/05tue2/05tue2-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/05/opinion/05tue2/05tue2-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/05/opinion/05tue2/05tue2-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Editorial',
#                         'print_page': '22',
#                         'pub_date': '2016-01-05T02:03:43+0000',
#                         'score': 14.994232,
#                         'snippet': 'Congressional Republicans won’t pass even '
#                                    'basic, sensible gun-safety measures, so '
#                                    'Mr. Obama is doing what he can through '
#                                    'executive actions.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Editorial',
#                         'uri': 'nyt://article/5dfe8f7c-1899-54d9-8ae7-17c5e58ddd47',
#                         'web_url': 'https://www.nytimes.com/2016/01/05/opinion/the-president-acts-on-gun-violence.html',
#                         'word_count': 634},
#                        {'_id': '56892f6638f0d81904703a02',
#                         'abstract': 'White House announces plans for '
#                                     'town-hall-style meeting, at which Pres '
#                                     'Obama and Atty Gen Loretta E Lynch will '
#                                     "discuss gun violence in America, nation's "
#                                     'need for increased gun control, and '
#                                     "administration's stepped-up "
#                                     'counterterrorism efforts; hour-long '
#                                     'event, which will take place at George '
#                                     'Mason University in Washington, DC, will '
#                                     'be broadcast on CNN. ',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By GARDINER HARRIS and '
#                                                'NICHOLAS FANDOS',
#                                    'person': [{'firstname': 'Gardiner',
#                                                'lastname': 'HARRIS',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None},
#                                               {'firstname': 'Nicholas',
#                                                'lastname': 'FANDOS',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 2,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Obama to Hold Town Hall Meeting '
#                                              'on Gun Violence',
#                                      'name': None,
#                                      'print_headline': 'Obama Plans a TV Forum '
#                                                        'to Address Gun '
#                                                        'Violence',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'persons',
#                                       'rank': 1,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 3,
#                                       'value': 'Lynch, Loretta E'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Terrorism'},
#                                      {'major': None,
#                                       'name': 'organizations',
#                                       'rank': 5,
#                                       'value': 'Islamic State in Iraq and '
#                                                'Syria (ISIS)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 6,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 412,
#                                         'legacy': {'xlarge': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-articleLarge.jpg',
#                                                    'xlargeheight': '412',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'National',
#                         'print_page': '10',
#                         'pub_date': '2016-01-04T00:00:00Z',
#                         'score': 14.279843,
#                         'snippet': 'The hourlong event will be televised on '
#                                    'CNN, and will come days after President '
#                                    'Obama meets with the attorney general to '
#                                    'discuss gun control.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/04/us/obama-to-hold-town-hall-meeting-on-gun-violence.html',
#                         'word_count': 500},
#                        {'_id': '5686a49b38f0d85a6c130307',
#                         'abstract': 'Pres Obama says in first weekly address '
#                                     'of 2016 that after months of deliberation '
#                                     'over issue, he plans to meet with Atty '
#                                     'Gen Loretta E Lynch to explore how to '
#                                     'sidestep Congress in his efforts to curb '
#                                     'gun violence.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By EMMARIE HUETTEMAN and '
#                                                'GARDINER HARRIS',
#                                    'person': [{'firstname': 'Emmarie',
#                                                'lastname': 'HUETTEMAN',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None},
#                                               {'firstname': 'Gardiner',
#                                                'lastname': 'HARRIS',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 2,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'Obama to Consider Executive '
#                                              'Actions on Gun Violence',
#                                      'name': None,
#                                      'print_headline': 'Obama and Attorney '
#                                                        'General to Discuss How '
#                                                        'to Curb Gun Violence',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 3,
#                                       'value': 'Lynch, Loretta E'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Executive Orders and '
#                                                'Memorandums'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'San Bernardino, Calif, '
#                                                'Shooting (2015)'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 400,
#                                         'legacy': {'xlarge': 'images/2016/01/02/us/02obamaweb/02obamaweb-articleLarge.jpg',
#                                                    'xlargeheight': '400',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'National',
#                         'print_page': '8',
#                         'pub_date': '2016-01-02T00:00:00Z',
#                         'score': 14.048296,
#                         'section_name': 'Politics',
#                         'snippet': 'President Obama will meet with Attorney '
#                                    'General Loretta E. Lynch on Monday to '
#                                    'discuss what he can do to curb gun '
#                                    'violence, sidestepping an entrenched '
#                                    'Congress.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/02/us/politics/obama-to-consider-executive-actions-on-gun-violence.html',
#                         'word_count': 589},
#                        {'_id': '5690ea1838f0d8376e3defa3',
#                         'blog': {},
#                         'byline': {'organization': 'THE NEW YORK TIMES',
#                                    'original': 'By THE NEW YORK TIMES',
#                                    'person': []},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'A Backyard Fight Club as an '
#                                              'Alternative to Gun Violence',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Murders, Attempted Murders and '
#                                                'Homicides'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Documentary Films and '
#                                                'Programs'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 3,
#                                       'value': 'Wilmore, Christopher (1978- )'},
#                                      {'major': None,
#                                       'name': 'glocations',
#                                       'rank': 4,
#                                       'value': 'Harrisonburg (Va)'}],
#                         'multimedia': [],
#                         'news_desk': 'National',
#                         'pub_date': '2016-01-10T00:00:00Z',
#                         'score': 13.185113,
#                         'snippet': 'After his friend was shot to death in '
#                                    '2013, Chris Wilmore began actively '
#                                    'recruiting people to settle their disputes '
#                                    'with gloves, not guns.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/10/us/a-backyard-fight-club-as-an-alternative-to-gun-violence.html',
#                         'word_count': 299},
#                        {'_id': '5690312f38f0d8376e3dee57',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': None,
#                                    'person': None},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Letters',
#                                      'kicker': 'Letters',
#                                      'main': 'Obama’s Plea to Reduce Gun '
#                                              'Violence',
#                                      'name': None,
#                                      'print_headline': 'Obama’s Plea to Reduce '
#                                                        'Gun Violence',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Obama, Barack'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 362,
#                                         'legacy': {'xlarge': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-articleLarge.jpg',
#                                                    'xlargeheight': '362',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Letters',
#                         'print_page': '18',
#                         'pub_date': '2016-01-09T00:00:00Z',
#                         'score': 13.010519,
#                         'snippet': 'Readers respond to an Op-Ed essay by the '
#                                    'president calling for the country to join '
#                                    'together to fight the gun crisis.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Letter',
#                         'web_url': 'https://www.nytimes.com/2016/01/09/opinion/obamas-plea-to-reduce-gun-violence.html',
#                         'word_count': 572},
#                        {'_id': '568c6a3538f0d803f4a0c585',
#                         'abstract': 'Jim Dwyer About New York column describes '
#                                     'evolution of Wear Orange campaign, which '
#                                     'began in New York City in October 2015 '
#                                     'when players in New Renaissance '
#                                     'Basketball Assn starting wearing orange '
#                                     'patches on jerseys to raise awareness '
#                                     'about gun violence; notes effort has '
#                                     'expanded to about 300 amateur basketball '
#                                     'teams across country.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By JIM DWYER',
#                                    'person': [{'firstname': 'Jim',
#                                                'lastname': 'DWYER',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'About New York',
#                                      'kicker': 'About New York',
#                                      'main': 'Wear Orange Campaign Enlists '
#                                              'Youth Basketball Players to '
#                                              'Spread Message on Gun Violence',
#                                      'name': None,
#                                      'print_headline': 'Children at Play Can '
#                                                        'Convey Sober Message',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Basketball'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'organizations',
#                                       'rank': 3,
#                                       'value': 'New Renaissance Basketball '
#                                                'Assn'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Uniforms'},
#                                      {'major': None,
#                                       'name': 'glocations',
#                                       'rank': 5,
#                                       'value': 'New York City'}],
#                         'multimedia': [],
#                         'news_desk': 'Metro',
#                         'print_page': '18',
#                         'pub_date': '2016-01-06T00:00:00Z',
#                         'score': 9.995066,
#                         'snippet': 'Jim Fox, a leader of a Long Island league '
#                                    'and of the Amateur Athletic Union in the '
#                                    'New York area, is helping to have patches '
#                                    'displayed on thousands of young '
#                                    'people&#8217;s uniforms.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/06/nyregion/wear-orange-campaign-enlists-youth-basketball-players-to-spread-message-on-gun-violence.html',
#                         'word_count': 725},
#                        {'_id': '56aa502c38f0d83460bc77db',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By TRYMAINE LEE',
#                                    'person': [{'firstname': 'Trymaine',
#                                                'lastname': 'LEE',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Opinion',
#                                      'kicker': 'Opinion',
#                                      'main': 'On the Beat of Black Lives and '
#                                              'Bloodshed',
#                                      'name': None,
#                                      'print_headline': 'Black Lives and '
#                                                        'Bloodshed',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Murders, Attempted Murders and '
#                                                'Homicides'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Blacks'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'Gun Control'},
#                                      {'major': 'N',
#                                       'name': 'glocations',
#                                       'rank': 4,
#                                       'value': 'United States'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Police Brutality, Misconduct '
#                                                'and Shootings'},
#                                      {'major': 'N',
#                                       'name': 'subject',
#                                       'rank': 6,
#                                       'value': 'Social Conditions and Trends'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 569,
#                                         'legacy': {'xlarge': 'images/2016/01/31/opinion/sunday/31lee/31lee-articleLarge.jpg',
#                                                    'xlargeheight': 569,
#                                                    'xlargewidth': 600},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbWide.jpg',
#                                                    'wideheight': 126,
#                                                    'widewidth': 190},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbStandard.jpg',
#                                                    'thumbnailheight': 75,
#                                                    'thumbnailwidth': 75},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'OpEd',
#                         'print_page': '2',
#                         'pub_date': '2016-01-28T17:30:19+0000',
#                         'score': 8.467804,
#                         'section_name': 'Sunday Review',
#                         'snippet': 'The exhausting dance between black death '
#                                    'and black scribe is journalism and '
#                                    'catharsis.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Op-Ed',
#                         'uri': 'nyt://article/13f1a070-97ab-52ea-b321-31961a3978cf',
#                         'web_url': 'https://www.nytimes.com/2016/01/31/opinion/sunday/on-the-beat-of-black-lives-and-bloodshed.html',
#                         'word_count': 1334},
#                        {'_id': '56a6a4fe38f0d82e67248955',
#                         'abstract': 'The Sanders campaign has mailed Iowa '
#                                     'voters literature that outlines his '
#                                     'record on gun control, suggesting how '
#                                     'much he is on the defensive on the issue '
#                                     'with the caucuses only a week away.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By JASON HOROWITZ',
#                                    'person': [{'firstname': 'Jason',
#                                                'lastname': 'HOROWITZ',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'blogpost',
#                         'headline': {'content_kicker': None,
#                                      'kicker': 'First Draft',
#                                      'main': 'Bernie Sanders Mailing in Iowa '
#                                              'Defends His Record on Guns',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'persons',
#                                       'rank': 1,
#                                       'value': 'Clinton, Hillary Rodham'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 2,
#                                       'value': 'Sanders, Bernard'},
#                                      {'major': None,
#                                       'name': 'glocations',
#                                       'rank': 1,
#                                       'value': 'Iowa'},
#                                      {'major': None,
#                                       'name': 'organizations',
#                                       'rank': 1,
#                                       'value': 'Brady Campaign to Prevent Gun '
#                                                'Violence'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Presidential Election of '
#                                                '2016'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 400,
#                                         'legacy': {'xlarge': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-articleLarge.jpg',
#                                                    'xlargeheight': '400',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Politics',
#                         'pub_date': '2016-01-25T17:41:06Z',
#                         'score': 7.323591,
#                         'section_name': 'Politics',
#                         'snippet': 'The Sanders campaign has mailed Iowa '
#                                    'voters literature that outlines his record '
#                                    'on gun control, suggesting how much he is '
#                                    'on the defensive on the issue with the '
#                                    'caucuses only a week away.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'Blog',
#                         'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/25/bernie-sanders-mailing-in-iowa-defends-his-record-on-guns/',
#                         'word_count': 455},
#                        {'_id': '569aa93b38f0d80d6e341fe2',
#                         'abstract': 'Editorial highlights analysis from group '
#                                     'Everytown for Gun Safety documenting '
#                                     'substantial number of Americans killed '
#                                     'each year by spouse, partner or family '
#                                     'member with firearm; notes federal and '
#                                     'state laws fail to prevent many domestic '
#                                     'abusers from accessing guns and calls for '
#                                     'closing of loopholes that allow abusers '
#                                     'to own such weapons.',
#                         'blog': {},
#                         'byline': {'organization': 'THE EDITORIAL BOARD',
#                                    'original': 'By THE EDITORIAL BOARD',
#                                    'person': []},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': 'Editorial',
#                                      'kicker': 'Editorial',
#                                      'main': 'Keep Guns Away From Abusers',
#                                      'name': None,
#                                      'print_headline': 'Keep Guns Away From '
#                                                        'Abusers',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Editorials'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Domestic Violence'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 3,
# ...
#                                     'Gun Violence Suppression Division, in '
#                                     'charge of investigations into illegal '
#                                     'firearms.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By J. DAVID GOODMAN',
#                                    'person': [{'firstname': 'J.',
#                                                'lastname': 'GOODMAN',
#                                                'middlename': 'David',
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'De Blasio to Announce New System '
#                                              'Dedicated to Addressing Gun '
#                                              'Crime in New York City',
#                                      'name': None,
#                                      'print_headline': 'De Blasio to Announce '
#                                                        'New System Dedicated '
#                                                        'to Addressing Gun '
#                                                        'Crime',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Courts and the Judiciary'},
#                                      {'major': None,
#                                       'name': 'glocations',
#                                       'rank': 3,
#                                       'value': 'New York City'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 4,
#                                       'value': 'de Blasio, Bill'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 5,
#                                       'value': 'Mondo, Suzanne M'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 6,
#                                       'value': 'Mullen, Cassandra M'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbWide.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbWide.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 399,
#                                         'legacy': {'xlarge': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-articleLarge.jpg',
#                                                    'xlargeheight': '399',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbStandard.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbStandard.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Metro',
#                         'print_page': '19',
#                         'pub_date': '2016-01-12T00:00:00Z',
#                         'score': 3.8948722,
#                         'snippet': 'Starting this month, people charged with '
#                                    'the possession of a firearm in the city '
#                                    'will be sent to State Supreme Court in '
#                                    'Brooklyn, which will preside over gun '
#                                    'arrest cases.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/12/nyregion/de-blasio-to-announce-new-system-dedicated-to-addressing-gun-crime-in-new-york-city.html',
#                         'word_count': 957},
#                        {'_id': '56a00ac538f0d80627b20b4c',
#                         'abstract': 'Gun violence is theme to many '
#                                     'documentaries screening at Sundance Film '
#                                     'Festival in Park City, Utah; filmmakers, '
#                                     'galvanized from spate of mass shootings '
#                                     'in Newtown, Aurora and other American '
#                                     'cities, hope movies at heavily publicized '
#                                     'event will lead to effective solution to '
#                                     'heartbreaking issue.',
#                         'blog': {},
#                         'byline': {'organization': None,
#                                    'original': 'By BROOKS BARNES',
#                                    'person': [{'firstname': 'Brooks',
#                                                'lastname': 'BARNES',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
#                                                'rank': 1,
#                                                'role': 'reported',
#                                                'title': None}]},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': None,
#                                      'main': 'The Sundance Film Festival '
#                                              'Trains Its Sights on the Gun '
#                                              'Debate',
#                                      'name': None,
#                                      'print_headline': 'Sundance Festival '
#                                                        'Trains Its Sights on '
#                                                        'Gun Debate',
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [{'major': None,
#                                       'name': 'subject',
#                                       'rank': 1,
#                                       'value': 'Movies'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 11,
#                                       'value': 'Schnack, A J'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 12,
#                                       'value': 'Soechtig, Stephanie'},
#                                      {'major': None,
#                                       'name': 'creative_works',
#                                       'rank': 13,
#                                       'value': 'Under the Gun (Movie)'},
#                                      {'major': None,
#                                       'name': 'creative_works',
#                                       'rank': 17,
#                                       'value': 'Dark Night (Movie)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 2,
#                                       'value': 'Sundance Film Festival (Park '
#                                                'City, Utah)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 3,
#                                       'value': 'Gun Control'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 4,
#                                       'value': 'Newtown, Conn, Shooting '
#                                                '(2012)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 5,
#                                       'value': 'Aurora, Colo, Shooting (2012)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 6,
#                                       'value': 'School Shootings and Armed '
#                                                'Attacks'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 7,
#                                       'value': 'San Bernardino, Calif, '
#                                                'Shooting (2015)'},
#                                      {'major': None,
#                                       'name': 'subject',
#                                       'rank': 8,
#                                       'value': 'Documentary Films and '
#                                                'Programs'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 9,
#                                       'value': 'Poitras, Laura'},
#                                      {'major': None,
#                                       'name': 'persons',
#                                       'rank': 10,
#                                       'value': 'Redford, Robert'}],
#                         'multimedia': [{'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 126,
#                                         'legacy': {'wide': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbWide-v2.jpg',
#                                                    'wideheight': '126',
#                                                    'widewidth': '190'},
#                                         'rank': 0,
#                                         'subType': 'wide',
#                                         'subtype': 'wide',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbWide-v2.jpg',
#                                         'width': 190},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 338,
#                                         'legacy': {'xlarge': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-articleLarge.jpg',
#                                                    'xlargeheight': '338',
#                                                    'xlargewidth': '600'},
#                                         'rank': 0,
#                                         'subType': 'xlarge',
#                                         'subtype': 'xlarge',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-articleLarge.jpg',
#                                         'width': 600},
#                                        {'caption': None,
#                                         'credit': None,
#                                         'crop_name': None,
#                                         'height': 75,
#                                         'legacy': {'thumbnail': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbStandard-v2.jpg',
#                                                    'thumbnailheight': '75',
#                                                    'thumbnailwidth': '75'},
#                                         'rank': 0,
#                                         'subType': 'thumbnail',
#                                         'subtype': 'thumbnail',
#                                         'type': 'image',
#                                         'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbStandard-v2.jpg',
#                                         'width': 75}],
#                         'news_desk': 'Culture',
#                         'print_page': '1',
#                         'pub_date': '2016-01-21T00:00:00Z',
#                         'score': 3.8909543,
#                         'snippet': 'Several selections at this year’s festival '
#                                    'are joining the national discussion about '
#                                    'mass shootings and gun control.',
#                         'source': 'The New York Times',
#                         'type_of_material': 'News',
#                         'web_url': 'https://www.nytimes.com/2016/01/21/movies/the-sundance-film-festival-trains-its-sights-on-the-gun-debate.html',
#                         'word_count': 1170}],
#               'meta': {'hits': 144, 'offset': 20, 'time': 18}},
#  'status': 'OK'}

# %%
articles_list
# Out:
# [{'web_url': 'https://www.nytimes.com/2016/01/05/opinion/the-president-acts-on-gun-violence.html',
#   'snippet': 'Congressional Republicans won’t pass even basic, sensible gun-safety measures, so Mr. Obama is doing what he can through executive actions.',
#   'print_page': '22',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/05/opinion/05tue2/05tue2-articleLarge.jpg',
#     'height': 726,
#     'width': 600,
#     'legacy': {'xlargewidth': 600,
#      'xlarge': 'images/2016/01/05/opinion/05tue2/05tue2-articleLarge.jpg',
#      'xlargeheight': 726},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/05/opinion/05tue2/05tue2-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/05/opinion/05tue2/05tue2-thumbWide.jpg',
#      'widewidth': 190,
#      'wideheight': 126},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/05/opinion/05tue2/05tue2-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': 75,
#      'thumbnail': 'images/2016/01/05/opinion/05tue2/05tue2-thumbStandard.jpg',
#      'thumbnailwidth': 75},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'The President Acts on Gun Violence',
#    'kicker': 'Editorial',
#    'content_kicker': 'Editorial',
#    'print_headline': 'The President Acts on Gun Violence',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Editorials',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2016-01-05T02:03:43+0000',
#   'document_type': 'article',
#   'news_desk': 'Editorial',
#   'byline': {'original': 'By THE EDITORIAL BOARD',
#    'person': [],
#    'organization': 'THE EDITORIAL BOARD'},
#   'type_of_material': 'Editorial',
#   '_id': '568b248038f0d85e74bd0b7b',
#   'word_count': 634,
#   'score': 14.994232,
#   'uri': 'nyt://article/5dfe8f7c-1899-54d9-8ae7-17c5e58ddd47'},
#  {'web_url': 'https://www.nytimes.com/2016/01/04/us/obama-to-hold-town-hall-meeting-on-gun-violence.html',
#   'snippet': 'The hourlong event will be televised on CNN, and will come days after President Obama meets with the attorney general to discuss gun control.',
#   'abstract': "White House announces plans for town-hall-style meeting, at which Pres Obama and Atty Gen Loretta E Lynch will discuss gun violence in America, nation's need for increased gun control, and administration's stepped-up counterterrorism efforts; hour-long event, which will take place at George Mason University in Washington, DC, will be broadcast on CNN. ",
#   'print_page': '10',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-articleLarge.jpg',
#     'height': 412,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-articleLarge.jpg',
#      'xlargeheight': '412'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/03/us/04townhall-webSUB/obama-firstdraft-SUB-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama to Hold Town Hall Meeting on Gun Violence',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Obama Plans a TV Forum to Address Gun Violence',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Obama, Barack',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 2, 'major': None},
#    {'name': 'persons', 'value': 'Lynch, Loretta E', 'rank': 3, 'major': None},
#    {'name': 'subject', 'value': 'Terrorism', 'rank': 4, 'major': None},
#    {'name': 'organizations',
#     'value': 'Islamic State in Iraq and Syria (ISIS)',
#     'rank': 5,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 6,
#     'major': None}],
#   'pub_date': '2016-01-04T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'byline': {'original': 'By GARDINER HARRIS and NICHOLAS FANDOS',
#    'person': [{'firstname': 'Gardiner',
#      'middlename': None,
#      'lastname': 'HARRIS',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Nicholas',
#      'middlename': None,
#      'lastname': 'FANDOS',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '56892f6638f0d81904703a02',
#   'word_count': 500,
#   'score': 14.279843},
#  {'web_url': 'https://www.nytimes.com/2016/01/02/us/politics/obama-to-consider-executive-actions-on-gun-violence.html',
#   'snippet': 'President Obama will meet with Attorney General Loretta E. Lynch on Monday to discuss what he can do to curb gun violence, sidestepping an entrenched Congress.',
#   'abstract': 'Pres Obama says in first weekly address of 2016 that after months of deliberation over issue, he plans to meet with Atty Gen Loretta E Lynch to explore how to sidestep Congress in his efforts to curb gun violence.',
#   'print_page': '8',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/02/us/02obamaweb/02obamaweb-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/02/us/02obamaweb/02obamaweb-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama to Consider Executive Actions on Gun Violence',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Obama and Attorney General to Discuss How to Curb Gun Violence',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': None},
#    {'name': 'persons', 'value': 'Lynch, Loretta E', 'rank': 3, 'major': None},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject',
#     'value': 'San Bernardino, Calif, Shooting (2015)',
#     'rank': 5,
#     'major': None}],
#   'pub_date': '2016-01-02T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Politics',
#   'byline': {'original': 'By EMMARIE HUETTEMAN and GARDINER HARRIS',
#    'person': [{'firstname': 'Emmarie',
#      'middlename': None,
#      'lastname': 'HUETTEMAN',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Gardiner',
#      'middlename': None,
#      'lastname': 'HARRIS',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '5686a49b38f0d85a6c130307',
#   'word_count': 589,
#   'score': 14.048296},
#  {'web_url': 'https://www.nytimes.com/2016/01/10/us/a-backyard-fight-club-as-an-alternative-to-gun-violence.html',
#   'snippet': 'After his friend was shot to death in 2013, Chris Wilmore began actively recruiting people to settle their disputes with gloves, not guns.',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'A Backyard Fight Club as an Alternative to Gun Violence',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Murders, Attempted Murders and Homicides',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Documentary Films and Programs',
#     'rank': 2,
#     'major': None},
#    {'name': 'persons',
#     'value': 'Wilmore, Christopher (1978- )',
#     'rank': 3,
#     'major': None},
#    {'name': 'glocations',
#     'value': 'Harrisonburg (Va)',
#     'rank': 4,
#     'major': None}],
#   'pub_date': '2016-01-10T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'byline': {'original': 'By THE NEW YORK TIMES',
#    'person': [],
#    'organization': 'THE NEW YORK TIMES'},
#   'type_of_material': 'News',
#   '_id': '5690ea1838f0d8376e3defa3',
#   'word_count': 299,
#   'score': 13.185113},
#  {'web_url': 'https://www.nytimes.com/2016/01/09/opinion/obamas-plea-to-reduce-gun-violence.html',
#   'snippet': 'Readers respond to an Op-Ed essay by the president calling for the country to join together to fight the gun crisis.',
#   'print_page': '18',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-articleLarge.jpg',
#     'height': 362,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-articleLarge.jpg',
#      'xlargeheight': '362'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/09/opinion/09Lguns-web/09Lguns-web-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama’s Plea to Reduce Gun Violence',
#    'kicker': 'Letters',
#    'content_kicker': 'Letters',
#    'print_headline': 'Obama’s Plea to Reduce Gun Violence',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': None}],
#   'pub_date': '2016-01-09T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Letters',
#   'byline': {'original': None, 'person': None, 'organization': None},
#   'type_of_material': 'Letter',
#   '_id': '5690312f38f0d8376e3dee57',
#   'word_count': 572,
#   'score': 13.010519},
#  {'web_url': 'https://www.nytimes.com/2016/01/06/nyregion/wear-orange-campaign-enlists-youth-basketball-players-to-spread-message-on-gun-violence.html',
#   'snippet': 'Jim Fox, a leader of a Long Island league and of the Amateur Athletic Union in the New York area, is helping to have patches displayed on thousands of young people&#8217;s uniforms.',
#   'abstract': 'Jim Dwyer About New York column describes evolution of Wear Orange campaign, which began in New York City in October 2015 when players in New Renaissance Basketball Assn starting wearing orange patches on jerseys to raise awareness about gun violence; notes effort has expanded to about 300 amateur basketball teams across country.',
#   'print_page': '18',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Wear Orange Campaign Enlists Youth Basketball Players to Spread Message on Gun Violence',
#    'kicker': 'About New York',
#    'content_kicker': 'About New York',
#    'print_headline': 'Children at Play Can Convey Sober Message',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Basketball',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 2, 'major': None},
#    {'name': 'organizations',
#     'value': 'New Renaissance Basketball Assn',
#     'rank': 3,
#     'major': None},
#    {'name': 'subject', 'value': 'Uniforms', 'rank': 4, 'major': None},
#    {'name': 'glocations', 'value': 'New York City', 'rank': 5, 'major': None}],
#   'pub_date': '2016-01-06T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Metro',
#   'byline': {'original': 'By JIM DWYER',
#    'person': [{'firstname': 'Jim',
#      'middlename': None,
#      'lastname': 'DWYER',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '568c6a3538f0d803f4a0c585',
#   'word_count': 725,
#   'score': 9.995066},
#  {'web_url': 'https://www.nytimes.com/2016/01/31/opinion/sunday/on-the-beat-of-black-lives-and-bloodshed.html',
#   'snippet': 'The exhausting dance between black death and black scribe is journalism and catharsis.',
#   'print_page': '2',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-articleLarge.jpg',
#     'height': 569,
#     'width': 600,
#     'legacy': {'xlargewidth': 600,
#      'xlarge': 'images/2016/01/31/opinion/sunday/31lee/31lee-articleLarge.jpg',
#      'xlargeheight': 569},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbWide.jpg',
#      'widewidth': 190,
#      'wideheight': 126},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': 75,
#      'thumbnail': 'images/2016/01/31/opinion/sunday/31lee/31lee-thumbStandard.jpg',
#      'thumbnailwidth': 75},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'On the Beat of Black Lives and Bloodshed',
#    'kicker': 'Opinion',
#    'content_kicker': 'Opinion',
#    'print_headline': 'Black Lives and Bloodshed',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Murders, Attempted Murders and Homicides',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Blacks', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'United States', 'rank': 4, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Police Brutality, Misconduct and Shootings',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Social Conditions and Trends',
#     'rank': 6,
#     'major': 'N'}],
#   'pub_date': '2016-01-28T17:30:19+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'section_name': 'Sunday Review',
#   'byline': {'original': 'By TRYMAINE LEE',
#    'person': [{'firstname': 'Trymaine',
#      'middlename': None,
#      'lastname': 'LEE',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Op-Ed',
#   '_id': '56aa502c38f0d83460bc77db',
#   'word_count': 1334,
#   'score': 8.467804,
#   'uri': 'nyt://article/13f1a070-97ab-52ea-b321-31961a3978cf'},
#  {'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/25/bernie-sanders-mailing-in-iowa-defends-his-record-on-guns/',
#   'snippet': 'The Sanders campaign has mailed Iowa voters literature that outlines his record on gun control, suggesting how much he is on the defensive on the issue with the caucuses only a week away.',
#   'abstract': 'The Sanders campaign has mailed Iowa voters literature that outlines his record on gun control, suggesting how much he is on the defensive on the issue with the caucuses only a week away.',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/25/us/25firstdraft-gross/25firstdraft-gross-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Bernie Sanders Mailing in Iowa Defends His Record on Guns',
#    'kicker': 'First Draft',
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Clinton, Hillary Rodham',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons', 'value': 'Sanders, Bernard', 'rank': 2, 'major': None},
#    {'name': 'glocations', 'value': 'Iowa', 'rank': 1, 'major': None},
#    {'name': 'organizations',
#     'value': 'Brady Campaign to Prevent Gun Violence',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 1, 'major': None},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 2,
#     'major': None}],
#   'pub_date': '2016-01-25T17:41:06Z',
#   'document_type': 'blogpost',
#   'news_desk': 'Politics',
#   'section_name': 'Politics',
#   'byline': {'original': 'By JASON HOROWITZ',
#    'person': [{'firstname': 'Jason',
#      'middlename': None,
#      'lastname': 'HOROWITZ',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Blog',
#   '_id': '56a6a4fe38f0d82e67248955',
#   'word_count': 455,
#   'score': 7.323591},
#  {'web_url': 'https://www.nytimes.com/2016/01/17/opinion/sunday/keep-guns-away-from-abusers.html',
#   'snippet': 'Shortcomings in federal and state law allow many domestic abusers to have access to firearms.',
#   'abstract': 'Editorial highlights analysis from group Everytown for Gun Safety documenting substantial number of Americans killed each year by spouse, partner or family member with firearm; notes federal and state laws fail to prevent many domestic abusers from accessing guns and calls for closing of loopholes that allow abusers to own such weapons.',
#   'print_page': '10',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/17/opinion/17sun2web/17sun2web-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/17/opinion/17sun2web/17sun2web-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/17/opinion/17sun2web/17sun2web-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/17/opinion/17sun2web/17sun2web-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/17/opinion/17sun2web/17sun2web-thumbStandard-v2.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/17/opinion/17sun2web/17sun2web-thumbStandard-v2.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Keep Guns Away From Abusers',
#    'kicker': 'Editorial',
#    'content_kicker': 'Editorial',
#    'print_headline': 'Keep Guns Away From Abusers',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Editorials',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject', 'value': 'Domestic Violence', 'rank': 2, 'major': None},
#    {'name': 'subject',
#     'value': 'Murders, Attempted Murders and Homicides',
#     'rank': 3,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Everytown for Gun Safety',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 5, 'major': None}],
#   'pub_date': '2016-01-17T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Editorial',
#   'section_name': 'Sunday Review',
#   'byline': {'original': 'By THE EDITORIAL BOARD',
#    'person': [],
#    'organization': 'THE EDITORIAL BOARD'},
#   'type_of_material': 'Editorial',
#   '_id': '569aa93b38f0d80d6e341fe2',
#   'word_count': 491,
#   'score': 6.946694},
#  {'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/12/hillary-clinton-accuses-bernie-sanders-of-not-standing-up-to-gun-lobby/',
#   'snippet': 'Hillary Clinton, appearing with the president of the Brady Campaign to Prevent Gun Violence, attacked Bernie Sanders on his 2005 vote to shield gunmakers from lawsuits.',
#   'abstract': 'Hillary Clinton, appearing with the president of the Brady Campaign to Prevent Gun Violence, attacked Bernie Sanders on his 2005 vote to shield gunmakers from lawsuits.',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/12/us/12firstdraft-sanders/12firstdraft-sanders-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Hillary Clinton Accuses Bernie Sanders of Not Standing Up to Gun Lobby',
#    'kicker': 'First Draft',
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Clinton, Hillary Rodham',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons', 'value': 'Sanders, Bernard', 'rank': 2, 'major': None},
#    {'name': 'glocations', 'value': 'Iowa', 'rank': 1, 'major': None},
#    {'name': 'organizations',
#     'value': 'Brady Campaign to Prevent Gun Violence',
#     'rank': 1,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Democratic Party',
#     'rank': 2,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'National Rifle Assn',
#     'rank': 3,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Quinnipiac University',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 1, 'major': None},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 2,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Primaries and Caucuses',
#     'rank': 3,
#     'major': None}],
#   'pub_date': '2016-01-12T14:37:47Z',
#   'document_type': 'blogpost',
#   'news_desk': 'Politics',
#   'section_name': 'Politics',
#   'byline': {'original': 'By PATRICK HEALY',
#    'person': [{'firstname': 'Patrick',
#      'middlename': None,
#      'lastname': 'HEALY',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Blog',
#   '_id': '5695569738f0d83e7cfe030c',
#   'word_count': 941,
#   'score': 5.5502744},
#  {'web_url': 'https://www.nytimes.com/2016/01/07/opinion/guns-tears-and-republicans.html',
#   'snippet': 'The critics in the G.O.P. who scolded the president for weeping while talking about shooting deaths have it wrong. We should all be crying.',
#   'print_page': '23',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-articleLarge-v2.jpg',
#     'height': 597,
#     'width': 600,
#     'legacy': {'xlargewidth': 600,
#      'xlarge': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-articleLarge-v2.jpg',
#      'xlargeheight': 597},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-thumbWide-v5.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-thumbWide-v5.jpg',
#      'widewidth': 190,
#      'wideheight': 126},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-thumbStandard-v5.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': 75,
#      'thumbnail': 'images/2014/11/01/opinion/kristof-circular/kristof-circular-thumbStandard-v5.jpg',
#      'thumbnailwidth': 75},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Guns, Tears and Republicans',
#    'kicker': 'Op-Ed Columnist',
#    'content_kicker': 'Op-Ed Columnist',
#    'print_headline': 'Guns,  Tears and Republicans',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Republican Party',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Cruz, Ted', 'rank': 5, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Christie, Christopher J',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 7, 'major': 'N'},
#    {'name': 'persons', 'value': 'Bush, Jeb', 'rank': 8, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Deaths (Fatalities)',
#     'rank': 9,
#     'major': 'N'}],
#   'pub_date': '2016-01-07T08:21:21+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'byline': {'original': 'By NICHOLAS KRISTOF',
#    'person': [{'firstname': 'Nicholas',
#      'middlename': None,
#      'lastname': 'KRISTOF',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Op-Ed',
#   '_id': '568e200638f0d82b2249c5da',
#   'word_count': 822,
#   'score': 4.458846,
#   'uri': 'nyt://article/fecc6aba-4548-5304-89df-9b18fe4c40c6'},
#  {'web_url': 'https://www.nytimes.com/2016/01/23/opinion/in-gun-debate-the-sides-arent-equal.html',
#   'snippet': 'Readers take issue with Nicholas Kristof’s stress on gun safety instead of gun control.',
#   'print_page': '18',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/23/opinion/23LkristofWeb/23kristofWeb-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'In Gun Debate, the Sides Aren’t Equal',
#    'kicker': 'Letters',
#    'content_kicker': 'Letters',
#    'print_headline': 'In Gun Debate, the Sides Aren’t Equal',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'National Rifle Assn',
#     'rank': 2,
#     'major': None},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 3,
#     'major': None}],
#   'pub_date': '2016-01-23T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Letters',
#   'byline': {'original': None, 'person': None, 'organization': None},
#   'type_of_material': 'Letter',
#   '_id': '56a27ffe38f0d85aa1bb1882',
#   'word_count': 666,
#   'score': 4.422299},
#  {'web_url': 'https://www.nytimes.com/2016/01/13/opinion/a-smarter-way-to-get-guns-off-the-street.html',
#   'snippet': 'Mayor Bill de Blasio announced two encouraging new approaches in pursuit of a safer city.',
#   'print_page': '20',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/13/opinion/13wed3web/13wed3web-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/13/opinion/13wed3web/13wed3web-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/13/opinion/13wed3web/13wed3web-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/13/opinion/13wed3web/13wed3web-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/13/opinion/13wed3web/13wed3web-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/13/opinion/13wed3web/13wed3web-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'A Smarter Way to Get Guns Off the Street',
#    'kicker': 'Editorial',
#    'content_kicker': 'Editorial',
#    'print_headline': 'A Smarter Way to Get Guns Off the Street',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Crime and Criminals',
#     'rank': 2,
#     'major': None},
#    {'name': 'persons', 'value': 'de Blasio, Bill', 'rank': 3, 'major': None},
#    {'name': 'organizations',
#     'value': 'Police Department (NYC)',
#     'rank': 4,
#     'major': None},
#    {'name': 'glocations', 'value': 'New York City', 'rank': 5, 'major': None}],
#   'pub_date': '2016-01-13T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Editorial',
#   'byline': {'original': 'By THE EDITORIAL BOARD',
#    'person': [],
#    'organization': 'THE EDITORIAL BOARD'},
#   'type_of_material': 'Editorial',
#   '_id': '569608f138f0d83e7cfe0513',
#   'word_count': 553,
#   'score': 4.3792977},
#  {'web_url': 'https://www.nytimes.com/2016/01/04/us/politics/state-focus-and-infusion-of-funding-buoy-gun-control-advocates.html',
#   'snippet': 'With tens of millions of dollars in contributions to spend, groups are looking to toughen state and local measures in ways that the Republican-led Congress has rejected on the federal level.',
#   'abstract': "Gun control advocates have won victories in number of states, including Connecticut and Delaware, backed by tens of millions of dollars donated to cause by backers like former New York City Mayor Michael R Bloomberg; combined with Pres Obama's expected use of executive authority to stem gun violence, gun control advocacy has gained new momentum in part due to shift in strategy away from trying to pass measures through Republican-held Congress.",
#   'print_page': '1',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2015/12/21/us/22guns-web1/22guns-web1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2015/12/21/us/22guns-web1/22guns-web1-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2015/12/21/us/22guns-web1/22guns-web1-articleLarge.jpg',
#     'height': 423,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2015/12/21/us/22guns-web1/22guns-web1-articleLarge.jpg',
#      'xlargeheight': '423'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2015/12/21/us/22guns-web1/22guns-web1-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2015/12/21/us/22guns-web1/22guns-web1-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'State Focus and Infusion of Funding Buoy Gun Control Advocates',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Battleground Shifts in Debate on Gun Control',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Law and Legislation',
#     'rank': 11,
#     'major': None},
#    {'name': 'subject', 'value': 'States (US)', 'rank': 2, 'major': None},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 3, 'major': None},
#    {'name': 'persons',
#     'value': 'Bloomberg, Michael R',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 5,
#     'major': None},
#    {'name': 'glocations', 'value': 'Connecticut', 'rank': 6, 'major': None},
#    {'name': 'glocations', 'value': 'Delaware', 'rank': 7, 'major': None},
#    {'name': 'organizations',
#     'value': 'National Rifle Assn',
#     'rank': 8,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Everytown for Gun Safety',
#     'rank': 9,
#     'major': None},
#    {'name': 'persons',
#     'value': 'McPike, Jeremy (1975- )',
#     'rank': 10,
#     'major': None}],
#   'pub_date': '2016-01-04T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Politics',
#   'byline': {'original': 'By ERIC LICHTBLAU',
#    'person': [{'firstname': 'Eric',
#      'middlename': None,
#      'lastname': 'LICHTBLAU',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '5689932338f0d845a9e6f1a8',
#   'word_count': 1715,
#   'score': 4.360565},
#  {'web_url': 'https://www.nytimes.com/2016/01/06/opinion/obamas-small-steps-on-gun-control.html',
#   'snippet': 'Readers discuss the president’s plans to expand background checks and increase enforcement of gun laws.',
#   'print_page': '22',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-articleLarge.jpg',
#     'height': 392,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-articleLarge.jpg',
#      'xlargeheight': '392'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/06/opinion/06LgunsWeb/06LgunsWeb-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama’s Small Steps on Gun Control',
#    'kicker': 'Letters',
#    'content_kicker': 'Letters',
#    'print_headline': 'Obama’s Small Steps on Gun Control',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None}],
#   'pub_date': '2016-01-06T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Letters',
#   'byline': {'original': None, 'person': None, 'organization': None},
#   'type_of_material': 'Letter',
#   '_id': '568c210638f0d803f4a0c4cb',
#   'word_count': 583,
#   'score': 4.324492},
#  {'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/21/gun-control-groups-say-bernie-sanders-is-the-wrong-candidate-to-support/',
#   'snippet': 'Groups devoted to gun control sent a letter to Democracy for America, which has endorsed Bernie Sanders for president, citing, in part, two crucial votes in Congress on gun safety, and saying “Senator Sanders was wrong on both of them.”',
#   'abstract': 'Groups devoted to gun control sent a letter to Democracy for America, which has endorsed Bernie Sanders for president, citing, in part, two crucial votes in Congress on gun safety, and saying “Senator Sanders was wrong on both of them.”',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-articleLarge.jpg',
#     'height': 390,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-articleLarge.jpg',
#      'xlargeheight': '390'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/21/us/21firstdraft-guns/21firstdraft-guns-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Gun Control Groups Say Bernie Sanders Is the Wrong Candidate to Support',
#    'kicker': 'First Draft',
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Clinton, Hillary Rodham',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons',
#     'value': 'Giffords, Gabrielle',
#     'rank': 2,
#     'major': None},
#    {'name': 'persons', 'value': 'Sanders, Bernard', 'rank': 3, 'major': None},
#    {'name': 'organizations',
#     'value': 'Americans for Responsible Solutions',
#     'rank': 1,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Democracy for America',
#     'rank': 2,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'National Rifle Assn',
#     'rank': 3,
#     'major': None},
#    {'name': 'organizations', 'value': 'Third Way', 'rank': 4, 'major': None},
#    {'name': 'subject', 'value': 'Endorsements', 'rank': 1, 'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 2, 'major': None},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 3,
#     'major': None}],
#   'pub_date': '2016-01-21T07:51:26Z',
#   'document_type': 'blogpost',
#   'news_desk': 'Politics',
#   'section_name': 'Politics',
#   'byline': {'original': 'By MAGGIE HABERMAN',
#    'person': [{'firstname': 'Maggie',
#      'middlename': None,
#      'lastname': 'HABERMAN',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Blog',
#   '_id': '56a0d4f138f0d80627b20d56',
#   'word_count': 528,
#   'score': 4.180942},
#  {'web_url': 'https://www.nytimes.com/2016/01/08/opinion/president-barack-obama-guns-are-our-shared-responsibility.html',
#   'snippet': 'I will not campaign for, vote for or support any candidate, even in my own party, who does not support common-sense gun reform.',
#   'print_page': '23',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#     'height': 374,
#     'width': 600,
#     'legacy': {'xlargewidth': 600,
#      'xlarge': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#      'xlargeheight': 374},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#      'widewidth': 190,
#      'wideheight': 126},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': 75,
#      'thumbnail': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#      'thumbnailwidth': 75},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Barack Obama: Guns Are Our Shared Responsibility',
#    'kicker': 'Op-Ed Contributor',
#    'content_kicker': 'Op-Ed Contributor',
#    'print_headline': 'Our Shared Responsibility',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Firearms', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2016-01-08T00:03:35+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'byline': {'original': 'By BARACK OBAMA',
#    'person': [{'firstname': 'Barack',
#      'middlename': None,
#      'lastname': 'OBAMA',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
# ...
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': 75,
#      'thumbnail': 'images/2016/01/05/us/05guns-web1/05guns-web1-thumbStandard.jpg',
#      'thumbnailwidth': 75},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama to Expand Gun Background Checks and Tighten Enforcement',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Obama to Expand Gun Sale Checks',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Law and Legislation',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Republican Party',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Ryan, Paul D Jr', 'rank': 7, 'major': 'N'},
#    {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 8, 'major': 'N'}],
#   'pub_date': '2016-01-04T21:28:28+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Politics',
#   'byline': {'original': 'By MICHAEL D. SHEAR and ERIC LICHTBLAU',
#    'person': [{'firstname': 'Michael',
#      'middlename': None,
#      'lastname': None,
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '568ae3ff38f0d85e74bd0ae3',
#   'word_count': 1083,
#   'score': 4.0081825,
#   'uri': 'nyt://article/034fedc2-4ed2-5330-9a55-d76ef5f990d6'},
#  {'web_url': 'https://www.nytimes.com/2016/01/08/us/politics/obama-gun-control-town-hall-cnn.html',
#   'snippet': 'In an intense but civil town-hall-style event broadcast live on television, activists pressed President Obama to justify his gun-control efforts.',
#   'abstract': 'Pres Obama discusses his gun control efforts at town-hall-style event broadcast live by CNN, going on defensive with gun rights activists; also states in New York Times Op-Ed article published same day that he will not support any candidates who oppose gun control measures.',
#   'print_page': '1',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/08/us/08obama-web02/08obama-web02-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/08/us/08obama-web02/08obama-web02-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/08/us/08obama-web02/08obama-web02-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/08/us/08obama-web02/08obama-web02-articleLarge.jpg',
#      'xlargeheight': '400'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/08/us/08obama-web02/08obama-web02-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/08/us/08obama-web02/08obama-web02-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Obama Pleads for Stricter Gun Laws and Faces Tough Questioning',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Obama Lays Out Case on Gun Laws ',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Obama, Barack',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 2, 'major': None},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 3,
#     'major': None},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Executive Orders and Memorandums',
#     'rank': 5,
#     'major': None},
#    {'name': 'organizations', 'value': 'CNN', 'rank': 6, 'major': None}],
#   'pub_date': '2016-01-08T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Politics',
#   'byline': {'original': 'By MICHAEL D. SHEAR',
#    'person': [{'firstname': 'Michael',
#      'middlename': None,
#      'lastname': None,
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '568e97b038f0d82b2249c749',
#   'word_count': 1191,
#   'score': 3.9926057},
#  {'web_url': 'https://www.nytimes.com/2016/01/07/us/politics/under-gun-rules-fbi-will-receive-health-data.html',
#   'snippet': 'State agencies and Social Security will disclose to the F.B.I. &#8220;protected health information&#8221; including those who are dangers to themselves or who cannot manage their own affairs.',
#   'abstract': "Pres Obama's gun control plan will allow state agencies and Social Security Administration to provide some protected mental health information to FBI in order to prevent those posing danger to themselves and others from obtaining guns; measure, coming in response to Republican pressure, draws complaints that it unfairly targets those with mental health issues as source of gun violence.",
#   'print_page': '14',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-articleLarge.jpg',
#     'height': 402,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-articleLarge.jpg',
#      'xlargeheight': '402'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/07/us/07hipaa-web/07hipaa-web-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'Under Gun Rules, F.B.I. Will Receive Health Data',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Under Gun Rules, F.B.I. Will Receive Health Data',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Mental Health and Disorders',
#     'rank': 2,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Patient Protection and Affordable Care Act (2010)',
#     'rank': 3,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Disability Insurance',
#     'rank': 4,
#     'major': None},
#    {'name': 'organizations',
#     'value': 'Justice Department',
#     'rank': 5,
#     'major': None},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 6, 'major': None},
#    {'name': 'organizations',
#     'value': 'Social Security Administration',
#     'rank': 7,
#     'major': None}],
#   'pub_date': '2016-01-07T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'Politics',
#   'byline': {'original': 'By ROBERT PEAR',
#    'person': [{'firstname': 'Robert',
#      'middlename': None,
#      'lastname': 'PEAR',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '568dbdb038f0d82b2249c4f5',
#   'word_count': 991,
#   'score': 3.9372892},
#  {'web_url': 'https://www.nytimes.com/2016/01/12/nyregion/de-blasio-to-announce-new-system-dedicated-to-addressing-gun-crime-in-new-york-city.html',
#   'snippet': 'Starting this month, people charged with the possession of a firearm in the city will be sent to State Supreme Court in Brooklyn, which will preside over gun arrest cases.',
#   'abstract': 'New York City Mayor Bill de Blasio is set to announce new system for addressing gun violence cases, responding to persistent shootings throughout city; included in plan is  dedicated gun court in Brooklyn that will work in tandem with 200-officer Gun Violence Suppression Division, in charge of investigations into illegal firearms.',
#   'print_page': '19',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbWide.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-articleLarge.jpg',
#     'height': 399,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-articleLarge.jpg',
#      'xlargeheight': '399'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/12/nyregion/12guncourt-web-1/12guncourt-web-1-thumbStandard.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'De Blasio to Announce New System Dedicated to Addressing Gun Crime in New York City',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'De Blasio to Announce New System Dedicated to Addressing Gun Crime',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Gun Control',
#     'rank': 1,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Courts and the Judiciary',
#     'rank': 2,
#     'major': None},
#    {'name': 'glocations', 'value': 'New York City', 'rank': 3, 'major': None},
#    {'name': 'persons', 'value': 'de Blasio, Bill', 'rank': 4, 'major': None},
#    {'name': 'persons', 'value': 'Mondo, Suzanne M', 'rank': 5, 'major': None},
#    {'name': 'persons',
#     'value': 'Mullen, Cassandra M',
#     'rank': 6,
#     'major': None}],
#   'pub_date': '2016-01-12T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Metro',
#   'byline': {'original': 'By J. DAVID GOODMAN',
#    'person': [{'firstname': 'J.',
#      'middlename': 'David',
#      'lastname': 'GOODMAN',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '569488ab38f0d80745b73673',
#   'word_count': 957,
#   'score': 3.8948722},
#  {'web_url': 'https://www.nytimes.com/2016/01/21/movies/the-sundance-film-festival-trains-its-sights-on-the-gun-debate.html',
#   'snippet': 'Several selections at this year’s festival are joining the national discussion about mass shootings and gun control.',
#   'abstract': 'Gun violence is theme to many documentaries screening at Sundance Film Festival in Park City, Utah; filmmakers, galvanized from spate of mass shootings in Newtown, Aurora and other American cities, hope movies at heavily publicized event will lead to effective solution to heartbreaking issue.',
#   'print_page': '1',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbWide-v2.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'wide': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbWide-v2.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subType': 'wide',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-articleLarge.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {'xlargewidth': '600',
#      'xlarge': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-articleLarge.jpg',
#      'xlargeheight': '338'},
#     'subType': 'xlarge',
#     'crop_name': None},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbStandard-v2.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnailheight': '75',
#      'thumbnail': 'images/2016/01/21/arts/21SUNDANCEJP1/21SUNDANCEJP1-thumbStandard-v2.jpg',
#      'thumbnailwidth': '75'},
#     'subType': 'thumbnail',
#     'crop_name': None}],
#   'headline': {'main': 'The Sundance Film Festival Trains Its Sights on the Gun Debate',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Sundance Festival Trains Its Sights on Gun Debate',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Movies',
#     'rank': 1,
#     'major': None},
#    {'name': 'persons', 'value': 'Schnack, A J', 'rank': 11, 'major': None},
#    {'name': 'persons',
#     'value': 'Soechtig, Stephanie',
#     'rank': 12,
#     'major': None},
#    {'name': 'creative_works',
#     'value': 'Under the Gun (Movie)',
#     'rank': 13,
#     'major': None},
#    {'name': 'creative_works',
#     'value': 'Dark Night (Movie)',
#     'rank': 17,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Sundance Film Festival (Park City, Utah)',
#     'rank': 2,
#     'major': None},
#    {'name': 'subject', 'value': 'Gun Control', 'rank': 3, 'major': None},
#    {'name': 'subject',
#     'value': 'Newtown, Conn, Shooting (2012)',
#     'rank': 4,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Aurora, Colo, Shooting (2012)',
#     'rank': 5,
#     'major': None},
#    {'name': 'subject',
#     'value': 'School Shootings and Armed Attacks',
#     'rank': 6,
#     'major': None},
#    {'name': 'subject',
#     'value': 'San Bernardino, Calif, Shooting (2015)',
#     'rank': 7,
#     'major': None},
#    {'name': 'subject',
#     'value': 'Documentary Films and Programs',
#     'rank': 8,
#     'major': None},
#    {'name': 'persons', 'value': 'Poitras, Laura', 'rank': 9, 'major': None},
#    {'name': 'persons', 'value': 'Redford, Robert', 'rank': 10, 'major': None}],
#   'pub_date': '2016-01-21T00:00:00Z',
#   'document_type': 'article',
#   'news_desk': 'Culture',
#   'byline': {'original': 'By BROOKS BARNES',
#    'person': [{'firstname': 'Brooks',
#      'middlename': None,
#      'lastname': 'BARNES',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': '56a00ac538f0d80627b20b4c',
#   'word_count': 1170,
#   'score': 3.8909543}]
